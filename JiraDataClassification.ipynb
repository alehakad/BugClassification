# %%
## for data
import json
import pandas as pd
import numpy as np

# %%
## language recognition
from langdetect import detect

# %%
from googletrans import Translator

# %%
## for processing
import re
import nltk

# %%
# for mutilang lemmatization
import simplemma

# %%
# for plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## for bag-of-words
from sklearn import feature_extraction, model_selection, naive_bayes, pipeline, manifold, preprocessing, feature_selection, metrics,svm
## for word embedding
import gensim
import gensim.downloader as gensim_api

# %%
translator = Translator()

# %%
# данные из jira
data_jira = pd.read_csv('data_from_jira.csv')
data_jira.shape
# Out:
# (10965, 2)

# %%
data_jira.head()
# Out:
#                                                 text company
# 0  {html} **From:** E.Amez@achenbach.de  \r\n **S...     ACH
# 1  {html} **From:** /O=EXCHANGELABS/OU=EXCHANGE A...     ACH
# 2  {html} **From:** /O=EXCHANGELABS/OU=EXCHANGE A...     ACH
# 3  {html} **From:** /O=EXCHANGELABS/OU=EXCHANGE A...     ACH
# 4  {html} **From:** E.Amez@achenbach.de  \r\n **S...     ACH

# %%
data_jira.shape
# Out:
# (10945, 2)

# %%
# удаление строк с проектами demo, integrate
data_jira = data_jira[(data_jira.company!="DEMO") & (data_jira.company!="INTEGRATE")]

# %%
data_jira.shape
# Out:
# (9865, 2)

# %%
text_langs = list(map(lambda x:detect(x)=="en" ,data_jira.text))

# %%
data_jira_not_en = data_jira[~np.array(text_langs)]

# %%
data_jira_not_en["company"].reset_index().groupby("company").count().sort_values(by="index")
# Out:
#            index
# company
# IKA            1
# CCZTOZNX       1
# CHDLTOSNX      1
# CSCH           1
# MB             1
# ...          ...
# TBN           33
# IMA           36
# VOS           36
# TURCK         79
# HER          117
#
# [135 rows x 1 columns]

# %%
# удаление строк не с английским языком
data_jira_en = data_jira[text_langs]

# %%
# распределение компаний
n_companies_sorted = data_jira_en["company"].reset_index().groupby("company").count().sort_values(by="index")

# %%
# удаление строк с 1 значениями
data_jira_en = data_jira_en[data_jira_en["company"].map(lambda x: n_companies_sorted.loc[x][0] > 1)]

# %%
data_jira_en.shape
# Out:
# (8590, 2)

# %%
data_jira_en["company"].reset_index().groupby("company").count().sort_values(by="index")
# Out:
#          index
# company
# ZSYS         2
# KVH          2
# SPAL         2
# MED          2
# EIS          2
# ...        ...
# EPDM       242
# SVC        283
# ECTR       334
# SIE        393
# DM         518
#
# [189 rows x 1 columns]

# %%
clean_data = data_jira_en.copy()

# %%
ps = nltk.stem.porter.PorterStemmer()
lem = nltk.stem.wordnet.WordNetLemmatizer()
# препроцессинг текста
def preprocess_text(text, flg_stemm=False, flg_lemm=True, lst_stopwords=None):
    # текст переводится в нижний регистр, оставляются только буквы
    text = re.sub('[^A-Za-z ]+', '', text.lower().strip())
    
    # токенизация - разбиение на слова
    lst_text = text.split()
    
    # удаление стоп слов
    if lst_stopwords is not None:
        lst_text = [word for word in lst_text if word not in 
                    lst_stopwords]
    
    # стемминг
    if flg_stemm:
        
        lst_text = [ps.stem(word) for word in lst_text]
         
    # леммантизация
    if flg_lemm:
        
        lst_text = [lem.lemmatize(word) for word in lst_text]
      
    
            
    # перевод обратно в текст
    text = " ".join(lst_text)
    return text

# %%
lst_stopwords = nltk.corpus.stopwords.words("english")
lst_stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
len(lst_stopwords)
# Out:
# 179

# %%
data_jira_en["text_clean"] = data_jira_en["text"].apply(lambda x: 
          preprocess_text(x, flg_stemm=True, flg_lemm=False, 
          lst_stopwords=lst_stopwords))

# %%
data_jira_en["company"].reset_index().groupby("company").count().sort_values(by="index")
# Out:
#          index
# company
# ZSYS         2
# KVH          2
# SPAL         2
# MED          2
# EIS          2
# ...        ...
# EPDM       242
# SVC        283
# ECTR       334
# SIE        393
# DM         518
#
# [189 rows x 1 columns]

# %%
# кол-во записей определенного класса
data_jira_en["company"].reset_index().groupby("company").count().sort_values(by="index").loc["DM"]
# Out:
# index    518
# Name: DM, dtype: int64

# %%
# компании с письмами только не на английском
set(data_jira_not_en["company"]) -set(data_jira_en["company"])
# Out:
# {'AGILEEDM',
#  'AMSC',
#  'APL',
#  'AQ',
#  'ARRIVAL',
#  'CCZTOZNX',
#  'EXDA',
#  'LECTRA',
#  'LUK',
#  'MYR',
#  'RLAB',
#  'ROE',
#  'RUS',
#  'ZZZINTERNAL'}

# %%
## split dataset
dtf_train, dtf_test = model_selection.train_test_split(data_jira_en, test_size=0.33,shuffle=True,stratify=data_jira_en["company"])
## get target
y_train = dtf_train["company"].values
y_test = dtf_test["company"].values

# %%
## Count (classic BoW)
vectorizer_bow = feature_extraction.text.CountVectorizer(max_features=10000, ngram_range=(1,2))

# %%
## Tf-Idf (advanced variant of BoW)
vectorizer = feature_extraction.text.TfidfVectorizer(max_features=10000, ngram_range=(1,2))

# %%
corpus = dtf_train["text_clean"]

# %%
vectorizer.fit(corpus)
X_train = vectorizer.transform(corpus)
dic_vocabulary = vectorizer.vocabulary_

# %%
X_train.shape
# Out:
# (5755, 10000)

# %%
corpus
# Out:
# 4353    html kbakgrundfoscom sent supportecad subject ...
# 7968    exactli follow situat new project modul havea ...
# 2786    html oxplmsolutiongmbhexorgouexchang administr...
# 6843    html oexchangelabsouexchang administr groupfyd...
# 7740    html oxplmsolutiongmbhexorgouexchang administr...
#                               ...
# 6095    html pavel sozonovski send andreklavehnlaempec...
# 5090    cae consult martina walter mailtomartinawalter...
# 9615    html stefanweberthyssenkruppcom sent nikolaeva...
# 282     html oexchangelabsouexchang administr groupfyd...
# 2759    html andreaskoppithermofishercom sent lychev m...
# Name: text_clean, Length: 5755, dtype: object

# %%
X_names[::-1]
# Out:
# ['zzzm',
#  'subject zzzm',
#  'npdi report',
#  'hour',
#  'npdi',
#  'pm walter',
#  'sv integr',
#  'martina cc',
#  'administrativegroupcnrecipientscndmitrykirillov send',
#  'assanbaev',
#  'deni assanbaev',
#  'sv',
#  'work hour',
#  'patrick',
#  'deni',
#  'googl',
#  'assanbaev subject',
#  'lidia lychev',
#  'wiethan dorothe',
#  'ml',
#  'denisassanbaevrdsoftwarecom',
#  'spent',
#  'dorothe cc',
#  'attachedbest',
#  'xxx',
#  'walter martina',
#  'enter',
#  'id id',
#  'id',
#  'zsa',
#  'subject zsa',
#  'radmin',
#  'dongl',
#  'ip',
#  'caegroup subject',
#  'caegroup',
#  'usb',
#  'cae vpn',
#  'licens valid',
#  'pc',
#  'registergericht freiburg',
#  'server',
#  'maier',
#  'get order',
#  'dmitryfor',
#  'vrdsecadteam',
#  'updat version',
#  'book',
#  'groupfydibohfspdltcnrecipientscncbcacfafdcccefeffdmitrykiri sent',
#  'eplan integr',
#  'nikolaeva subject',
#  'config',
#  'zeppelin',
#  'zep',
#  'wiederhold',
#  'harder',
#  'eplan xplm',
#  'consol',
#  'hide',
#  'cintegrexelibintegratestartuprbin',
#  'zw datei',
#  'betreff eplan',
#  'timei',
#  'pdf',
#  'document use',
#  'thatth',
#  'neuen',
#  'der schnittstel',
#  'anpassung',
#  'need time',
#  'wg eplan',
#  'zeiss',
#  'subject zeiss',
#  'dr',
#  'holling',
#  'olafhollingerzeisscom',
#  'olafhollingerzeisscom sent',
#  'html olafhollingerzeisscom',
#  'regardsdipl olaf',
#  'carl',
#  'carl zeiss',
#  'olaf hollingercad',
#  'olaf holling',
#  'hollingercad',
#  'holling dipl',
#  'dipl olaf',
#  'mueller guido',
#  'peterdr marku',
#  'peterdr',
#  'oberkochen',
#  'monz dr',
#  'monz',
#  'mller dr',
#  'metz dr',
#  'metz',
#  'matthia metz',
#  'ludwin monz',
#  'ludwin',
#  'lamprecht',
#  'karl lamprecht',
#  'jochen peterdr',
#  'jochen',
#  'dr ludwin',
#  'dr jochen',
#  'dr christian',
#  'christian mller',
#  'servic infrastructurecarl',
#  'infrastructurecarl zeiss',
#  'infrastructurecarl',
#  'sbieej busi',
#  'sbieej',
#  'hollingercad electron',
#  'electron sbieej',
#  'busi servic',
#  'dr dieter',
#  'zeiss agheadquart',
#  'webercommerci regist',
#  'webercommerci',
#  'vat reg',
#  'regist ulm',
#  'reg de',
#  'presid ceodr',
#  'oberkochen germanychairman',
#  'marku webercommerci',
#  'lamprecht presid',
#  'kurzboard manag',
#  'kurzboard',
#  'hrb vat',
#  'germanychairman supervisori',
#  'germanychairman',
#  'dieter kurzboard',
#  'ceodr matthia',
#  'ceodr',
#  'agheadquart oberkochen',
#  'agheadquart',
#  'guido',
#  'zeisspromenad jena',
#  'zeisspromenad',
#  'zeiss agcarl',
#  'phone olafhollingerzeisscommailtoolafhollingerzeisscomwwwzeisscomhttpwwwzeisscom',
#  'olafhollingerzeisscommailtoolafhollingerzeisscomwwwzeisscomhttpwwwzeisscom carl',
#  'olafhollingerzeisscommailtoolafhollingerzeisscomwwwzeisscomhttpwwwzeisscom',
#  'jena germani',
#  'agcarl zeisspromenad',
#  'agcarl',
#  'jena',
#  'presid',
#  'manag dr',
#  'board dr',
#  'mueller',
#  'holling olaf',
#  'de html',
#  'fpr',
#  'dieter',
#  'dr karl',
#  'test list',
#  'fum',
#  'hello pavel',
#  'wilk mueller',
#  'lychev beat',
#  'reg',
#  'bestl marku',
#  'bestl',
#  'el document',
#  'poxleitn frank',
#  'poxleitn',
#  'germani phone',
#  'es el',
#  'fpr document',
#  'el',
#  'dirti flag',
#  'mller',
#  'supervisori board',
#  'gmbhmailtomaximlychevxplmcomsubmit boxhttpsftapixplmcomsubmitmaximlychevxplmcom',
#  'pavel',
#  'supervisori',
#  'point check',
#  'dirti',
#  'roh',
#  'dtype',
#  'check list',
#  'ecn',
#  'sozonovski',
#  'characterist',
#  'new point',
#  'addit file',
#  'beat',
#  'new issu',
#  'busi',
#  'tobia',
#  'respond',
#  'jan',
#  'winkler tobia',
#  'tt',
#  'pleas forward',
#  'alreadi use',
#  'upgrad profil',
#  'pc hello',
#  'open integr',
#  'mebest',
#  'integr dialog',
#  'protocol',
#  'lychev jira',
#  'alexeilebedevxplmcom kirillov',
#  'fyi',
#  'send lebedev',
#  'mainten',
#  'walter eugen',
#  'maxim maximlychevxplmcom',
#  'profil hello',
#  'profil version',
#  'zacharymaywaynetrailcom',
#  'jason',
#  'frock',
#  'zach',
#  'zacharymaywaynetrailcom sent',
#  'may zach',
#  'mayhtml',
#  'html zacharymaywaynetrailcom',
#  'subject wtt',
#  'wayn trail',
#  'wayn',
#  'trail',
#  'wtt',
#  'frock jason',
#  'releas bom',
#  'item number',
#  'profil sp',
#  'catalogu',
#  'count',
#  'descript field',
#  'famili',
#  'may',
#  'integr see',
#  'integr issu',
#  'ftp server',
#  'wilo',
#  'subject wilo',
#  'eilebrecht',
#  'eilebrecht benjamin',
#  'html benjamineilebrechtwilocom',
#  'benjamineilebrechtwilocom sent',
#  'benjamineilebrechtwilocom',
#  'benjamin subject',
#  'reinelt',
#  'strrd convert',
#  'strrd',
#  'ep',
#  'gru best',
#  'convert msg',
#  'msg',
#  'hw',
#  'matthia subject',
#  'subvers',
#  'pdfa',
#  'tht',
#  'old materi',
#  'right reserv',
#  'shall',
#  'part list',
#  'thank youbest',
#  'werma',
#  'dirk',
#  'materi number',
#  'dtypexml',
#  'work directori',
#  'cideon',
#  'log check',
#  'wilk subject',
#  'haveani',
#  'prfen',
#  'cc beat',
#  'hello dmitryattach',
#  'lebedev pavel',
#  'washtec',
#  'subject washtec',
#  'helmut assum',
#  'bei washtec',
#  'washtec profil',
#  'pm helmut',
#  'assum cc',
#  'assum',
#  'integr interfac',
#  'document docinno',
#  'bei',
#  'mglich',
#  'integr problem',
#  'wald',
#  'waldmann',
#  'subject wald',
#  'mbaermannwaldmanncom',
#  'mbaermannwaldmanncom cc',
#  'wald save',
#  'brmann',
#  'zaier',
#  'seedfil',
#  'doubl click',
#  'dmitri sozonovski',
#  'open origin',
#  'dim',
#  'variant name',
#  'hello andreaswev',
#  'andreaswev',
#  'gmbhmailtomaximlychevxplmcommailtomaximlychevxplmcomsubmit boxftapixplmcomsubmitmaximlychev',
#  'boxftapixplmcomsubmitmaximlychev',
#  'solut gmbhmailtomaximlychevxplmcommailtomaximlychevxplmcomsubmit',
#  'gmbhmailtomaximlychevxplmcommailtomaximlychevxplmcomsubmit',
#  'pm wilk',
#  'beat cc',
#  'pavel subject',
#  'send becker',
#  'vt',
#  'vincotech',
#  'septemb maxim',
#  'standard releas',
#  'invoic',
#  'ovington alexei',
#  'step need',
#  'part process',
#  'attach current',
#  'question need',
#  'kienzler subject',
#  'standard',
#  'integr specif',
#  'maximthank',
#  'start point',
#  'user manual',
#  'wiethan dorotheewiethanxplmcom',
#  'end week',
#  'gmbhmartinawalterxplmcommailtomartinawalterxplmcom offic',
#  'gmbhmartinawalterxplmcommailtomartinawalterxplmcom',
#  'viessmann',
#  'regard frank',
#  'orcadci',
#  'ci',
#  'dmitrykirillov alexej',
#  'next time',
#  'desc',
#  'vossloh rail',
#  'rail',
#  'vrail',
#  'ronni',
#  'bertragung von',
#  'bertragung',
#  'possibl implement',
#  'eplan nach',
#  'part get',
#  'von eplan',
#  'bertrag',
#  'test custom',
#  'length',
#  'xlsx',
#  'vo',
#  'subject vo',
#  'kiep',
#  'vossloh',
#  'jansen',
#  'kroppen',
#  'vo vossloh',
#  'kroppen juergen',
#  'refresh partsubassi',
#  'partsubassi',
#  'juergen',
#  'partsubassi log',
#  'slp',
#  'vo bom',
#  'slp aoaprolog',
#  'aoaprolog',
#  'aoaprolog slp',
#  'regardslidia html',
#  'spezifik',
#  'articl log',
#  'christophhtml',
#  'process articl',
#  'eintrg',
#  'hello christophw',
#  'vmi',
#  'subject vmi',
#  'deken',
#  'rdekensvmigroupcom',
#  'vri',
#  'cadpdm',
#  'smoonsvmigroupcom',
#  'html smoonsvmigroupcom',
#  'rdekensvmigroupcom sent',
#  'kind regardsstefan',
#  'pluimer',
#  'regard ronald',
#  'regardsstefan',
#  'moon',
#  'make pdf',
#  'part select',
#  'gener file',
#  'remark',
#  'bom plm',
#  'profil eplan',
#  'vitron',
#  'vit',
#  'menuid',
#  'name integrateact',
#  'releas test',
#  'interfac hello',
#  'zusammenfassung au',
#  'vbsnx',
#  'mentor vx',
#  'mentorgraph',
#  'file log',
#  'vx',
#  'vb',
#  'xp',
#  'go use',
#  'onto',
#  'vattenfal',
#  'dialog save',
#  'vat',
#  'flexlm',
#  'integr und',
#  'first draft',
#  'regard andrea',
#  'nov supportecad',
#  'dmitri simmat',
#  'find comment',
#  'id number',
#  'onlin meet',
#  'alreadi sent',
#  'includ chang',
#  'necessari',
#  'regardschristophhtml',
#  'chang made',
#  'uec',
#  'last releas',
#  'offic fax',
#  'offic st',
#  'next shipment',
#  'vpn',
#  'hous',
#  'physic',
#  'sch pcb',
#  'closer',
#  'offic',
#  'golden',
#  'tri run',
#  'turck',
#  'jrgensmey',
#  'jrgensmey michael',
#  'michaeljuergensmeyerturckcom',
#  'vom brock',
#  'brock',
#  'subject turck',
#  'michaeljuergensmeyerturckcom sent',
#  'html michaeljuergensmeyerturckcom',
#  'cc jrgensmey',
#  'rdiger',
#  'brock rdiger',
#  'ruedigervombrocketurckcom sent',
#  'ruedigervombrocketurckcom',
#  'html ruedigervombrocketurckcom',
#  'regard michael',
#  'michael jrgensmey',
#  'werner turck',
#  'bkenkamp',
#  'hybrid',
#  'bkenkamp thorsten',
#  'halver',
#  'html carstenfiebigturckcom',
#  'carstenfiebigturckcom sent',
#  'carstenfiebigturckcom',
#  'turck gmbh',
#  'turck turck',
#  'beierfeld',
#  'dmitrywir',
#  'fiebig',
#  'werner',
#  'rdiger subject',
#  'michael subject',
#  'jrgensmey html',
#  'hallo dmitrywir',
#  'gerri',
#  'aw turck',
#  'juergensmey',
#  'regard rdiger',
#  'rdiger vom',
#  'kg goethestr',
#  'goethestr',
#  'vandecrommert',
#  'goethestr halver',
#  'tusa',
#  'fiebig carsten',
#  'layoutkonstrukt',
#  'gerryvandecrommertturckcom',
#  'html gerryvandecrommertturckcom',
#  'gerryvandecrommertturckcom sent',
#  'dimitryi',
#  'halver tel',
#  'oder sonstig',
#  'ceslogfilesconsdefloglog',
#  'ceslogfilesconsdefloglog ceslogfilesconsdefloglog',
#  'mr juergensmey',
#  'datasheet',
#  'layoutkonstrukt interfacegert',
#  'interfacegert werner',
#  'interfacegert',
#  'mit freundlichen',
#  'wwwturckcom',
#  'per haft',
#  'kg per',
#  'haft',
#  'eigler',
#  'hallo',
#  'bom layout',
#  'regard html',
#  'knnte',
#  'dbg',
#  'read articl',
#  'haft ge',
#  'ge werner',
#  'ge',
#  'weitergab oder',
#  'untersagt bitt',
#  'trade busi',
#  'ist ihnen',
#  'empfangen',
#  'die empfangen',
#  'contain trade',
#  'busi secret',
#  'sonstig',
#  'search plmlog',
#  'plmlog',
#  'freundlichen',
#  'refd tp',
#  'read histori',
#  'histori entrylog',
#  'foundlog read',
#  'entrylog read',
#  'entrylog',
#  'zusammenwir',
#  'hallo zusammenwir',
#  'hereof',
#  'error herebi',
#  'content hereof',
#  'nutzen',
#  'iserlohn hra',
#  'enthlt betrieb',
#  'betrieb',
#  'amtsgericht iserlohn',
#  'iserlohn',
#  'bekommen',
#  'untersagt',
#  'haben ist',
#  'co kg',
#  'cc walter',
#  'read personslog',
#  'personslog',
#  'vervielfltigung weitergab',
#  'hrb wichtig',
#  'hra hrb',
#  'halver registergericht',
#  'empfangen email',
#  'email ausdrcklich',
#  'ein vervielfltigung',
#  'ausdrcklich untersagt',
#  'ausdrcklich',
#  'modellog look',
#  'articl propertieslog',
#  'nutzung de',
#  'geschtzt oder',
#  'den empfnger',
#  'bestimmt sollten',
#  'sml',
#  'pick place',
#  'foundlog',
#  'wichtig hinwei',
#  'personslog refresh',
#  'hinwei',
#  'ist ausschlielich',
#  'bitt benachrichtigen',
#  'benachrichtigen',
#  'log refd',
#  'tkp',
#  'subject tkp',
#  'ullmann',
#  'xenia',
#  'christoph ullmann',
#  'risti',
#  'xenia risti',
#  'altium db',
#  'sascha',
#  'cid',
#  'alexand subject',
#  'part batch',
#  'oracl databas',
#  'batch',
#  'lgv',
#  'kaufmann alexand',
#  'solut gmbhhtml',
#  'gmbhhtml',
#  'lebedev dmitrykirillov',
#  'groupfydibohfspdltcnrecipientscncaaefcaaefmaximlych send',
#  'groupfydibohfspdltcnrecipientscncaaefcaaefmaximlych',
#  'administr groupfydibohfspdltcnrecipientscncaaefcaaefmaximlych',
#  'configur test',
#  'thi',
#  'hartmann',
#  'subject thi',
#  'stefanweberthyssenkruppcom',
#  'stefanweberthyssenkruppcom sent',
#  'html stefanweberthyssenkruppcom',
#  'blke',
#  'blke thoma',
#  'aw thi',
#  'regardsdipl ing',
#  'ing stefan',
#  'moritz',
#  'weber html',
#  'hartmann moritz',
#  'ing',
#  'hartmann udo',
#  'thomasboelkethyssenkruppcom',
#  'best regardsthoma',
#  'regardsthoma',
#  'tkf',
#  'abschlieen',
#  'weber stefan',
#  'cc hartmann',
#  'best regardsdipl',
#  'regardsthoma blkehtml',
#  'blkehtml',
#  'html thomasboelkethyssenkruppcom',
#  'projekt abschlieen',
#  'cc blke',
#  'kstrebelbcttechnologycom',
#  'mr weber',
#  'regardsdipl',
#  'thyssenkrupp',
#  'integr tc',
#  'gren best',
#  'eplan eplan',
#  'fault',
#  'chang workflow',
#  'nikolaeva html',
#  'freundlichen gren',
#  'gren',
#  'html lidia',
#  'workflow',
#  'nikolaeva',
#  'stamp pdf',
#  'tc server',
#  'file design',
#  'updat project',
#  'draw frame',
#  'design need',
#  'thank sven',
#  'frame',
#  'project file',
#  'design altium',
#  'draw',
#  'depart',
#  'ae',
#  'dde',
#  'cr',
#  'cannot get',
#  'hostid',
#  'mr rohrbach',
#  'subject test',
#  'ordsoftwareoufirst administrativegroupcnrecipientscndmitrykirillov',
#  'administrativegroupcnrecipientscndmitrykirillov',
#  'te',
#  'bilo',
#  'nuzhno',
#  'sent pavel',
#  'html ordsoftwareoufirst',
#  'bi',
#  'outlook',
#  'cc sozonovski',
#  'lost',
#  'pictur',
#  'vse',
#  'theben',
#  'tbn',
#  'subject tbn',
#  'tbn theben',
#  'muellerreis',
#  'theben ag',
#  'subject theben',
#  'haigerloch',
#  'proalpha',
#  'mllerreis',
#  'andrea theben',
#  'andrea muellerreis',
#  'gru andrea',
#  'mr muellerreis',
#  'wwwthebend',
#  'andreasmuellerreiserthebend',
#  'mllerreis andrea',
#  'draw editor',
#  'email und',
#  'hohenbergstra',
#  'haigerloch hohenbergstra',
#  'fax wwwthebend',
#  'gunther',
#  'hohenbergstra haigerloch',
#  'haigerloch fon',
#  'unverzglich',
#  'und sind',
#  'und jeder',
#  'sind nur',
#  'sie adressiert',
#  'jeder bermittelt',
#  'gestattet confidenti',
#  'die person',
#  'der adressat',
#  'bitt unverzglich',
#  'bermittelt anhang',
#  'bermittelt',
#  'adressiert',
#  'weitergab und',
#  'unverzglich den',
#  'person bestimmt',
#  'hello maxim',
#  'muellerreis leiter',
#  'amtsgericht stuttgart',
#  'maxim pleas',
#  'aufsichtsrat gunther',
#  'postfach haigerloch',
#  'ag postfach',
#  'seiner',
#  'mit freundlichem',
#  'nur fr',
#  'wwwthebend vertraulichkeitshinwei',
#  'vertraulichkeitshinwei',
#  'und seiner',
#  'de aufsichtsrat',
#  'hellberg sitz',
#  'hellberg',
#  'gunther hellberg',
#  'hello sven',
#  'log extract',
#  'vor han',
#  'renner vorsitzend',
#  'renner',
#  'han renner',
#  'plot',
#  'news auf',
#  'andreasmuellerreiserthebend theben',
#  'messag subject',
#  'vorstand thoma',
#  'ilayoutmentor',
#  'homepag wwwthebend',
#  'der homepag',
#  'verffentlichung dieser',
#  'und verffentlichung',
#  'bestimmt die',
#  'absend da',
#  'fon fax',
#  'fon',
#  'freundlichem gru',
#  'confidenti intend',
#  'raumailtoadmincaeconsultcom sent',
#  'knnen vertraulich',
#  'istfal sie',
#  'istfal',
#  'rdsoftwar gmbh',
#  'rdsoftwar',
#  'sven raumailtoadmincaeconsultcom',
#  'raumailtoadmincaeconsultcom',
#  'haigerloch handelsregist',
#  'ban',
#  'aufsichtsrat',
#  'lebedevsubject',
#  'item name',
#  'ban theben',
#  'freundlichem',
#  'gmbh mailtomaximlychevrdsoftwarecom',
#  'lychev rdsoftwar',
#  'jeder',
#  'sven origin',
#  'die sie',
#  'baur',
#  'dxdesign',
#  'goe vor',
#  'confidenti note',
#  'vorstand',
#  'postfach',
#  'gru',
#  'log convert',
#  'tbn sp',
#  'date thu',
#  'rcl',
#  'handelsregist amtsgericht',
#  'leiter',
#  'maxim lychev',
#  'ilayoutmentorepcbpcb',
#  'hellomaxim',
#  'rcl pcb',
#  'ezpdfoutputex',
#  'maximlychev rdsoftwar',
#  'mech',
#  'sven maxim',
#  'grau',
#  'donnerstag oktob',
#  'perman',
#  'problem mit',
#  'walter sent',
#  'file look',
#  'eplanp',
#  'anew',
#  'oktob',
#  'swa',
#  'swa problem',
#  'subject swa',
#  'swarovski',
#  'peterwinklerswarovskicom',
#  'peterwinklerswarovskicom sent',
#  'html peterwinklerswarovskicom',
#  'fasser',
#  'winkler',
#  'groupfydibohfspdltcnrecipientscnffabaaedcedabcbfsupporteca sent',
#  'groupfydibohfspdltcnrecipientscnffabaaedcedabcbfsupporteca',
#  'administr groupfydibohfspdltcnrecipientscnffabaaedcedabcbfsupporteca',
#  'eseri',
#  'bom tc',
#  'own',
#  'updat part',
#  'file found',
#  'scan',
#  'attachedhello',
#  'archiv attachedhello',
#  'ivanciuc',
#  'chri ivanciuc',
#  'wallac',
#  'scott wallac',
#  'wireless',
#  'sierra wireless',
#  'sierra',
#  'subject sw',
#  'cintegrateexelibintegratestartuprbin',
#  'cc jeff',
#  'ime subject',
#  'dupgroupuhfeatur',
#  'cc caradonna',
#  'part orcad',
#  'block',
#  'plm item',
#  'caecon perman',
#  'resolv problem',
#  'librari sync',
#  'transistor',
#  'manufacturerpart',
#  'evalin evalevalin',
#  'subject svc',
#  'tesat',
#  'inova',
#  'bitzer',
#  'carnaud',
#  'molex',
#  'concord',
#  'bruker',
#  'bourn',
#  'buckhout cc',
#  'magna',
#  'concord pro',
#  'buckhout',
#  'wittenstein',
#  'simplecondit',
#  'sattributetyp',
#  'yuri',
#  'david buckhout',
#  'dominik',
#  'lbnl',
#  'prokhorov alexei',
#  'subject bruker',
#  'prokhorov',
#  'pro',
#  'conflict',
#  'new properti',
#  'confer',
#  'issu best',
#  'descript problem',
#  'soa',
#  'find way',
#  'regardsyuri',
#  'easiest',
#  'alli',
#  'updat design',
#  'new column',
#  'deploy',
#  'newer version',
#  'design properti',
#  'may need',
#  'sozonovski dmitri',
#  'stratec',
#  'jdittusstrateccom',
#  'jdittusstrateccom sent',
#  'html jdittusstrateccom',
#  'dittu',
#  'subject stratec',
#  'dittu jenni',
#  'rout',
#  'anton',
#  'alog',
#  'schaltplan',
#  'beateiv',
#  'strama',
#  'subject strama',
#  'reiner christian',
#  'reiner',
#  'schult',
#  'schult christoph',
#  'hamdi',
#  'kind regard',
#  'testreport',
#  'christoph subject',
#  'send rupietta',
#  'christoph cc',
#  'rupietta christoph',
#  'christophpleas find',
#  'christophpleas',
#  'christophi',
#  'storengi',
#  'instal result',
#  'advic',
#  'knowthank',
#  'version profil',
#  'attach find',
#  'dmitrycan pleas',
#  'upload ftp',
#  'version includ',
#  'type field',
#  'sprue',
#  'jame byrn',
#  'byrn',
#  'bolger',
#  'jame',
#  'chri bolger',
#  'grodeckipcb design',
#  'grodeckipcb',
#  'mccall',
#  'graham mccall',
#  'byrn cc',
#  'graham',
#  'cc chri',
#  'safeti product',
#  'fireangel',
#  'chri',
#  'marku raoul',
#  'bare board',
#  'regist england',
#  'look forward',
#  'alter',
#  'plc',
#  'pleas advis',
#  'error hi',
#  'groupfydibohfspdltcnrecipientscnebfdabbdcceddsupport sent',
#  'groupfydibohfspdltcnrecipientscnebfdabbdcceddsupport',
#  'administr groupfydibohfspdltcnrecipientscnebfdabbdcceddsupport',
#  'mcad',
#  'pcb layout',
#  'bare',
#  'relationship',
#  'unexpect',
#  'disappear',
#  'day',
#  'resel',
#  'want instal',
#  'wehav',
#  'exampl design',
#  'see follow',
#  'deep',
#  'dont see',
#  'custom want',
#  'ping',
#  'repli',
#  'willb',
#  'potenti',
#  'wewil',
#  'present',
#  'sortimat',
#  'sor',
#  'sontag',
#  'subject sor',
#  'witzel',
#  'itemst',
#  'page properti',
#  'mslog',
#  'gerhard',
#  'itemst mslog',
#  'plmlog itemst',
#  'look itemst',
#  'itemst foundlog',
#  'updat modul',
#  'pruefer',
#  'mslog search',
#  'bernd',
#  'pruefer bezeichnungmsest',
#  'mslog updat',
#  'item attributesdescriptionst',
#  'descriptionmsest itemst',
#  'descriptionmsest',
#  'bezeichnungst descriptionmsest',
#  'bezeichnungst',
#  ...]

# %%
# отбор признаков для уменьшения размерности матрицы с помощью хи-квадрат

# %%
y = dtf_train["company"]
X_names = vectorizer.get_feature_names()
p_value_limit = 0.0001
dtf_features = pd.DataFrame()
for cat in np.unique(y):
    chi2, p = feature_selection.chi2(X_train, y==cat)
    dtf_features = dtf_features.append(pd.DataFrame(
                   {"feature":X_names, "score":p, "y":cat}))
    dtf_features = dtf_features.sort_values(["y","score"], 
                    ascending=[True,False])
    dtf_features = dtf_features[dtf_features["score"]<p_value_limit]
X_names = dtf_features["feature"].unique().tolist()

# %%
X_train
# Out:
# <5755x10000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 445208 stored elements in Compressed Sparse Row format>

# %%
len(X_names)
# Out:
# 5164

# %%
for cat in np.unique(y):
    print("# {}:".format(cat))
    print("  . selected features:",
         len(dtf_features[dtf_features["y"]==cat]))
    print("  . top features:", ",".join(
dtf_features[dtf_features["y"]==cat]["feature"].values))
    print(" ")
# Out:
# # ACH:
#   . selected features: 13
#   . top features: send apr,profil hello,talk mr,pdf ausgab,pdffile,fwd aw,eingab,doc inno,metadaten,quantiti bom,subject ach,ach,achenbach
#
# # ACTIA:
#   . selected features: 32
#   . top features: advancebest,xplm connector,cad doc,orcad ci,tsd,innov,connector hi,ac,core,item bom,gener,part cad,bom plm,ara sp,issu xplm,pcba,subject plm,supportbest,cad document,cad,core design,gaudel,gaudel jeanmichel,exporttyp,pong,johan pong,html johanpongeactiafr,johanpongeactiafr sent,johan,johanpongeactiafr,subject actia,actia
#
# # ADMINUI:
#   . selected features: 13
#   . top features: popup,thedocu,buckhout cc,error error,editor,send david,ui,beta,log see,result get,error report,admin,env
#
# # ADS:
#   . selected features: 192
#   . top features: destroy,lychev rdsoftwar,gmbh,synchron part,mail tomartinawaltercaeconsultcom,tomartinawaltercaeconsultcom web,updat librari,issu synchron,sent montag,montag april,sie,geschftsfhrereugen,geschftsfhrereugen kienzler,receiv email,informationen,wwwcaeconsultcom geschftsfhrereugen,consult gmbh,sie bitt,wiethan subject,martinawaltercaeconsultcom,mentor librari,hrb mailtomaximlychevrdsoftwarecom,unauthor,gmbhmailtomaximlychevrdsoftwarecom maxim,mailtomaximlychevrdsoftwarecom,email,eugen kienzler,tc item,error pleas,mailtomaximlychevcaeconsultcom gesendet,part batch,regard frank,andor,dipl,gren ia,tce,legaci project,mailtomaximlychevrdsoftwarecom mailtomaximlychevcaeconsultcom,wait wait,thereof,pleas notifi,absend,start workflow,email error,sind,kienzler,erhalten,deutschland germani,hello eugen,adressat,kopieren,dies,consult gmbhmailtomaximlychevcaeconsultcom,gmbhmailtomaximlychevcaeconsultcom,hello best,task ad,regard maxim,destroy email,eugen,echterdingen,echterdingen deutschland,den absend,brandstett frankwrot,frankwrot,frankwrot hi,sie dies,von brandstett,isprimaryno,stuttgart,borderdataasc,wwwadstecd,sofort,intendedrecipi,brandstett frankmailtofbrandstetteradstecd,frankmailtofbrandstetteradstecd,adressat sind,sind oder,stuttgart hrb,classif tree,rechtlich,gestattet,defect ad,cc eugen,wenn sie,sowi die,lychev cae,nicht gestattet,senderimmedi,part thereof,email may,sowi,oder dies,unauthor copi,gmbhmailtomaximlychevcaeconsultcom brandstett,gmbh sitz,sofort den,undod,absend und,juli tobrandstett,und vernichten,vernichten,vernichten sie,dieser mail,senderimmedi destroy,undod rechtlich,ruf,martinawaltercaeconsultcomdorothe,martinawaltercaeconsultcomdorothe wiethan,strictlyforbidden mailtomaximlychevrdsoftwarecom,bitt sofort,andor privileg,privileg inform,die unbefugteweitergab,unbefugteweitergab,unbefugteweitergab dieser,ad,materi part,sind nicht,gmbh mailtomaximlychevcaeconsultcom,lychevmailtomaximlychevcaeconsultcom sent,lychevmailtomaximlychevcaeconsultcom,maxim lychevmailtomaximlychevcaeconsultcom,kienzler martinawaltercaeconsultcomdorothe,notifi senderimmedi,verwendung,intendedrecipi receiv,geschaeftsfuehr,gestattet email,erhalten habeninformieren,habeninformieren,habeninformieren sie,containconfidenti,may containconfidenti,email unauthor,informationen wenn,use materi,hrb geschaeftsfuehr,registergericht stuttgart,dasunerlaubt,dasunerlaubt kopieren,derrichtig,derrichtig adressat,email dasunerlaubt,nicht derrichtig,subject ad,mailtofbrandstetteradstecd,geschaeftsfuehr dipl,geschuetzt,mail sind,rechtlich geschuetzt,irrtuemlich,speidel,frank brandstett,containconfidenti andor,inform intendedrecipi,sitz leinfeldenechterdingen,copi disclosuredistribut,disclosuredistribut,disclosuredistribut use,strictlyforbidden,thereof strictlyforbidden,anderweitig,anderweitig verwendung,dipl thoma,email enthaeltvertraulich,email irrtuemlich,enthaeltvertraulich,enthaeltvertraulich undod,geschuetzt informationen,irrtuemlich erhalten,jeglich,jeglich anderweitig,kopieren jeglich,leinfeldenechterdingen registergericht,speidel dies,thoma speidel,verwendung sowi,leinfeldenechterdingen,mailtomaximlychevcaeconsultcom,ad sp,tobrandstett,tobrandstett frank,adstec gmbh,pde,dies email,frank,ad save,frank cc,brandstett frank,mr brandstett,adstec,brandstett
#
# # ADV:
#   . selected features: 16
#   . top features: wilk cc,found new,plm creat,meet today,sent dmitri,timeout,http,drill,data hello,open new,manuel,adv,kirillov beat,occurr,nithin,advantest
#
# # AGILE:
#   . selected features: 20
#   . top features: regardsborishtml,clae cc,buckhout,integr configur,david buckhout,readi,pro,publish,send scott,becker cc,weekbest,configur use,administr groupfydibohfspdltcnrecipientscncddbccfbdecafyuryprokho,groupfydibohfspdltcnrecipientscncddbccfbdecafyuryprokho,regardsyuri,concord pro,andreaspleas,send andrea,version support,concord
#
# # ALP:
#   . selected features: 28
#   . top features: altium,mainli,new altium,lebedevsubject,continu test,outjob,draw header,cc paul,stabl,alexej lebedevsubject,architect,ovington sent,data sourc,support altium,infor,septemb dmitri,altium integr,infor plm,paul,green,terri,campbel,miller,paul miller,riki,jana,aileen,alpha
#
# # ALTTOSNX:
#   . selected features: 33
#   . top features: neutral,protelsnx,skip,mandatori,log error,warn log,error log,log warn,log fatal,log log,log creat,mandatori field,log compil,pars,log protelsnx,sch file,geometri,pars sch,arc,shape,arc locat,field radiu,geometri shape,line skip,radiu,radiu defin,reason mandatori,shape arc,skip reason,jul log,cii,cii line,locat fileebsebsschdoca
#
# # AQUA:
#   . selected features: 18
#   . top features: ccadmincaeconsultcom,databas use,ftp account,lebedev gregori,one one,shouldb,kirillov wrote,folder name,tuesday decemb,itlook,gregori liokumovichsvenraucaeconsultcom,catalog,whichi,project folder,lebedev denisassanbaevrdsoftwarecom,cae hello,patch ship,aqua
#
# # AR:
#   . selected features: 44
#   . top features: dsn,send clae,filefold,scott,ema,clae,klein,cc mark,jeff,cc gari,jeff ime,scott cc,ime subject,gari,ime,carter subject,carter,gari carter,bill,httpsftapixplmcomsubmitscottclaesxplmcomhttpsftapixplmcomsubmitscottclaesxplmcom,claesxplm,claesxplm solut,aml,mobil httpsftapixplmcomsubmitscottclaesxplmcomhttpsftapixplmcomsubmitscottclaesxplmcom,tmp part,gerri,blockedhttpwwwxplmcomhttpwwwxplmcomscottclaesxplmcommobil,incwwwxplmcomhttpwwwxplmcom,solut incwwwxplmcomhttpwwwxplmcom,incwwwxplmcomhttpwwwxplmcom blockedhttpwwwxplmcomhttpwwwxplmcomscottclaesxplmcommobil,cip,tmp,sent alexei,administr groupfydibohfspdltcnrecipientscneffeafbaefcecascottcla,groupfydibohfspdltcnrecipientscneffeafbaefcecascottcla,groupfydibohfspdltcnrecipientscneffeafbaefcecascottcla sent,eco,ricardo,subject amazon,subject ar,ar,amazon robot,robot,amazon
#
# # ARAS:
#   . selected features: 23
#   . top features: iom,claim,rb,pm brand,cintegrateexelibintegrateintegratemodulerbin,ara releas,alexeialexeilebedevxplmcom,lebedev alexeialexeilebedevxplmcom,christian,xclass,thale,isabel,zhelokov bori,brand,dobiasch,zhelokov,bori,cc zhelokov,ara product,brand christian,administr guid,ara,subject ara
#
# # ASM:
#   . selected features: 86
#   . top features: dialog save,instal use,fix pad,mnchen,padsintegr,dmitri kirillovalexei,kirillovalexei,kirillovalexei lebedev,lp,ovington martina,licenc,sourc refer,hyperlinkhttpcaeserverrdsbrowseasmasm,guenter lauber,lauber,lauber mike,mr braun,projectid,gener partner,guenter,kg regist,munich hrb,partner asm,agileplm,spec file,germani commerci,munich germani,teamw,commerci registri,noformat,deutschland tel,offic munich,rupertmayerstr mnchen,braun asm,asm plm,plm rupertmayerstr,mnchen deutschland,pad integr,kg asm,registri munich,rupertmayerstr,hotlin,stefan,manfr subject,asm save,braun egon,program part,egonbraunasmptcom sent,html egonbraunasmptcom,asm pad,system gmbh,pad,cc moerwald,manuela,aw asm,regard egon,egon braun,asm asm,feuereck,feuereck manuela,egonbraunasmptcom,assembl system,mrwald,youwith,munich,schnelling html,stefan schnelling,youwith best,manfr,asm assembl,asm tcepad,tcepad,schnelling,egon,asm integr,schnellingerhtml,stefan schnellingerhtml,braun,moerwald,moerwald manfr,regard stefan,html stefanschnellingerasmptcom,stefanschnellingerasmptcom sent,stefanschnellingerasmptcom,subject asm,asm
#
# # ASS:
#   . selected features: 24
#   . top features: martina simmat,chang document,simmat sent,nftstl,administr groupfydibohfspdltcnrecipientscnrenato,groupfydibohfspdltcnrecipientscnrenato,groupfydibohfspdltcnrecipientscnrenato simmat,attach instal,dear support,project number,innov part,teileart,integ,need chang,creat revis,part revis,creat modul,neue revis,integr need,meet minut,need estim,must ad,subject ass,ass
#
# # ASYS:
#   . selected features: 24
#   . top features: sml,slave,enthlt vertraulich,subassembl,unbefugt,wire,telefonisch,inform contain,email mr,bom structur,im profil,dmitri rupietta,elektrokonstrukt,elektrisch,elcad,mang,martin,regard martin,martin zeh,mr zeh,zeh martin,subject asi,zeh,asi
#
# # BAH:
#   . selected features: 25
#   . top features: answer within,dayth,dayth intern,issuessystemat,issuessystemat send,new issuessystemat,within dayth,support cc,geht,dump avail,datasheet,pm support,singl part,gregoryliokumovich,octob pm,plugin,neuer,elcad,maschinenbau,profil server,string articleattribut,articleattribut,subject bah,bahmuel,bah
#
# # BDT:
#   . selected features: 16
#   . top features: cpm,cadenc,err,sr,bereich,friday may,mailtomartinawaltercaeconsultcoms,walter mailtomartinawaltercaeconsultcoms,dem ftp,pcaprojectno,sergej,vassiliadi tryfon,vassiliadi,tryfon,subject bdt,bdt
#
# # BEC:
#   . selected features: 20
#   . top features: maxim kirillov,file zip,problem relat,find problem,zip archiv,relat file,check licens,problem report,problem licens,report pleas,assign new,attachedhtml,archiv attachedhtml,new pc,sir,new server,send feb,eplan problem,anja,bec
#
# # BESI:
#   . selected features: 21
#   . top features: error unabl,test machin,christoph subject,eci,rupietta subject,test licens,copi project,integr error,mr fuch,releas use,damag,rudolf,knobloch,fuch cc,agil client,rudolf knobloch,georg,fuch,georg fuch,subject besi,besi
#
# # BKH:
#   . selected features: 22
#   . top features: problem run,prefer,former,integr run,publish part,wednesday septemb,eco,sync librari,signific,next step,dxdatabook,datum tue,actingfor,actingfor sven,sep von,bidirect,pmto,pad integr,particular,friday april,bit version,steve
#
# # BMN:
#   . selected features: 43
#   . top features: christophpleas,chang valu,nftstl,gern,noch die,christophpleas find,fehlend,nikolaeva lidia,juli rupietta,backup file,scan file,schoernerma,schoernerma caecon,direkt,hello christophpleas,christoph simmat,artikel,lmgrd,lmgrd lmgrdslog,lmgrdslog,stcklistenbertrag,dankmit,dankmit freundlichen,stcklistenvergleichsdialog,administr groupfydibohfspdltcnrecipientscneaacbffdc,groupfydibohfspdltcnrecipientscneaacbffdc,groupfydibohfspdltcnrecipientscneaacbffdc sent,sent nikolaeva,schoerner,kindl,regardsmarc schrner,schrner html,regardsmarc,html marcschoernerbaumannautomationcom,marcschoernerbaumannautomationcom sent,best regardsmarc,marcschoernerbaumannautomationcom,bmn baumann,schrner,subject baumann,subject bmn,bmn,baumann
#
# # BROOKS:
#   . selected features: 30
#   . top features: caradonna,stay,mark lebedev,altium,file folder,instal issu,altium design,connector instal,altium librari,caradonna mark,suffix,andrea caradonna,hutsch marc,project templat,agil,pm caradonna,previou revis,altium databas,pm lychev,autom,specif hello,design agil,parrillo darren,arnold,brook autom,raymond arnold,parrillo,raymond,darren,brook
#
# # BRUC:
#   . selected features: 15
#   . top features: co,plant,thing,home,hi alexeii,ag,gmbh co,gmbh sitz,verwaltung,transact,geschftsfhrung,hr,wizard,catalog,maschinenbau
#
# # BU:
#   . selected features: 30
#   . top features: versionierung,par,integr chang,patch integr,accordingli,ce,ohn,eigenschaft,normblatt,integr solut,edgar,ohn sap,ernst edgar,ernst,cc kremer,angelikakremerburkertcom,angelikakremerburkertcom sent,html angelikakremerburkertcom,fahrbach,patric subject,angelika,kremer angelika,dinkel patric,patric,subject bu,dinkel,brkert,kremer,bu,buerkert
#
# # BULT:
#   . selected features: 47
#   . top features: comparison report,wednesday septemb,bomelectr,load visualdesignapilog,visualdesignapilog,localhost integr,quiet,code log,eptqulog,eptqulog part,number eptqulog,compass,epttbslog part,epttbslog,number epttbslog,obwohl,der stcklist,ervlog,ervlog part,number ervlog,singlelog ad,singlelog,elog,elog part,number elog,psp,eplan finish,auto quiet,nosplash,nosplash auto,beschreibung,execut cprogram,quiet frame,alt,wieder,eeslog,eeslog part,number eeslog,numberlog,numberlog part,part numberlog,bg,kai,kai deutschlnder,bltmann,deutschlnder,bult
#
# # CAR:
#   . selected features: 86
#   . top features: admincaeconsultcomalexeicaeconsultcom,graham,hi maxim,pawel,mentor,sso,st,ee,cintegrexelibintegratestartuprbin,aml,altium support,quotat,wiethandorothe,databook,cell,version altium,bompn,chadzynski,pawel chadzynski,effect,wipro,iomdll,trigger,mailtomaximcaeconsultcom sent,caecon may,load pli,douglasfeckcarestreamhealthcom,douglasfeckcarestreamhealthcom offic,mailtomaximcaeconsultcom,maxim mailtomaximcaeconsultcom,car csh,bom xl,pwr,date subject,youtub,feck wrote,facebook,cach,wwwcarestreamhealthcom,wwwcarestreamhealthcom carestream,twitter,twitter facebook,us twitter,maxim dougla,field eda,ebom,douglasfeckcarestreamcom,hudson,lynn hudson,research develop,thank doug,develop effect,eliez tuber,feck dougla,engin research,eliez,process engin,feck process,car bom,follow us,ny follow,st rochest,verona st,health verona,car integr,tuber,ny,verona,lynn,hello doug,doug feck,rochest,rochest ny,carestream health,csh,health,send dougla,carestream,feck cc,doug,subject car,pli,dougla feck,dougla,feck,car
#
# # CDS:
#   . selected features: 45
#   . top features: jar,exist project,cip,dll,sozonovski alexei,ofus,object,regardspavelhtml,rduser,workspac,sent sozonovski,groupfydibohfspdltcnrecipientscnccaacfcacfbdpavelsozon send,seidman,yuk seidman,ime,json,jeff ime,administr groupfydibohfspdltcnrecipientscnccaacfcacfbdpavelsozon,groupfydibohfspdltcnrecipientscnccaacfcacfbdpavelsozon,debugplm,orcad cip,action item,sent pavel,edm integr,yuk,jeff,datamodel agil,ema,allegro edm,edm,administr ccecedmlogg,ccecedmlogg,polari,polari rduser,patil lebedev,cc deepak,kesharwani cc,cd,subject cd,kesharwani,nikunj kesharwani,patil,deepak patil,nikunj,deepak
#
# # CHDLTOSNX:
#   . selected features: 23
#   . top features: clink qmanhtml,qmanhtml,regard sven,clink,know whether,design need,schneider,lychev alexej,fwd,sven origin,raumailtosvenraucaeconsultcom,sven raumailtosvenraucaeconsultcom,raumailtosvenraucaeconsultcom sent,bnl,work best,erzeugt,freitag dezemb,cadenc allegro,tomaxim,tomaxim lychev,data file,mitsubishi,chdlsnx
#
# # CHDLTOZNX:
#   . selected features: 19
#   . top features: issu error,maxim thank,frank,download file,hrb mailtomaximlychevrdsoftwarecom,asepar,von cae,nt,refdes,heinrichhertzstr,gmbh heinrichhertzstr,hotfix,regard frank,spb,digitaltest,denzlingen,mr lychev,mailtosupportcaeconsultcom,chdlznx
#
# # CNTRO:
#   . selected features: 20
#   . top features: user guid,ergebni,mi,anschlieend,speichern nach,new instal,stcklist,wurden,christoph kirillov,werd,custom specif,startet,morgen,spezifik,lidiacan,profil updat,mang,pf,cntro,centrotherm
#
# # COM:
#   . selected features: 28
#   . top features: updat exist,mainli,subject question,licens valid,integr modul,send nov,send sep,ye,servic,maintain,consist,ref,pop,oct,testinstal,parttyp,oracl,afternoon,technic,duringth,systembest,test instal,remot access,prepar updat,need defin,profil part,preliminari,technic servic
#
# # CONTACT:
#   . selected features: 29
#   . top features: becker alexei,rest api,kerstin,administr groupfydibohfspdltcnrecipientscncdeaeccddeacaalexanderk,groupfydibohfspdltcnrecipientscncdeaeccddeacaalexanderk,strae,schulz,alexand,groupfydibohfspdltcnrecipientscncdeaeccddeacaalexanderk send,addit attribut,classifi part,andfil,sso,mentor xpedit,ika,daniel kruse,kruse,filetyp,alexand kirillov,cimdb,contact,cdb,sersa,cim databas,jen rosebrock,rosebrock,jen,subject contact,cim
#
# # CRE:
#   . selected features: 38
#   . top features: log search,start use,integr profil,sunday,plm log,model log,updat see,xplm support,vr,uncount,itemfunct,itemfunct found,ab,test interfac,august pm,van,hostidani,van der,hostidani featur,heereweg ab,tom de,verzonden,de graaff,graaff,aan,heereweg,onderwerp,manuel,capurro diaz,mcapurrocremercom,diaz,liss,ab liss,see electr,manuel capurro,capurro,cre,cremer
#
# # CSCH:
#   . selected features: 29
#   . top features: issu open,nevertheless,problem part,lychev rdsoftwar,mailtomaximlychevrdsoftwarecom,rd,needto,main problem,properti valu,rdsoftwar gmbh,host,concept,assanbaev subject,mailtomaximlychevrdsoftwarecom origin,parti,compar,origin design,gmbh mailtomaximlychevrdsoftwarecom,document releas,need enhanc,rau cc,eda system,retain,septemb maxim,xp,chnage,releas ship,schematicsappl,rd parti
#
# # CSTOSNX:
#   . selected features: 25
#   . top features: ofus,rohrbach,geehrter herr,stop error,log creat,sehr geehrter,snx,log compil,intern error,net name,testit,log log,ftl,cadstar,schematicsappl,caecon,log build,lmgrd lmgrd,httinger,lmgrd,maierallap caecon,maierallap licens,maierallap,cstosnx,cssnx
#
# # CUBIC:
#   . selected features: 26
#   . top features: supportecad subject,wont,pleas find,relat,altium connector,sent supportecad,integr connector,public,zip,altium,archiv attach,problem report,attachedhtml,archiv,archiv attachedhtml,file zip,problem relat,find problem,zip archiv,relat file,report pleas,innov,cubic,altium problem,innov altium,subject innov
#
# # DEMATIC:
#   . selected features: 16
#   . top features: hidden,lychev alexei,item creat,design data,nx,cc clae,cc maxim,enovia,josh,clae cc,chang order,true eda,sent scott,write fals,acad,eda design
#
# # DEVOPS:
#   . selected features: 21
#   . top features: rubi,chang code,maxim maximlychevxplmcom,sweswpdm,henri,plm server,provid inform,krick,herwig,user enter,hinz,use creat,inour,branch,cc herwig,herwig hinz,marco,ask user,hennig,marco hennig,jenkin
#
# # DFF:
#   . selected features: 66
#   . top features: ftpcaeconsultgmbhcomftpftpcaeconsultgmbhcom user,horn,hellow,silent,readabl,erik,tsd,cid,erik horn,tce server,redesign,altiumdefectclosedfix dffhttpcaeserversecurequicksearchjspasearchstringdffpush,zipfil,materialnumm,arnold,altiumdesign,namen,cc erik,new variant,aenderung,ovington alexei,dffhttpcaeserversecurequicksearchjspasearchstringdffpush,upload ftpcaeconsultgmbhcomftpftpcaeconsultgmbhcom,fritz,lychevw,mr lychevw,button creat,altiumtaskclosedfix,thoma cc,rateex,gre,cminteg,creat assembl,dff push,altiumdefectclosedfix,thoma,schnaich,dr fritz,fritz faulhab,horn alexei,send schneider,regardsfreundlich,knapich sven,aw dff,regardsfreundlich gre,dff integr,knapich,camp tarek,tarek,la,maah andrea,schneider thoma,maah,camp,la camp,gre thoma,de la,schneider html,faulhab,thoma schneider,html thomasschneiderfaulhaberd,thomasschneiderfaulhaberd sent,subject dff,thomasschneiderfaulhaberd,schneider,dff
#
# # DIONEX:
#   . selected features: 44
#   . top features: havent yet,oper guid,pend,issu test,ralf,gmbhmailtomaximlychevxplmcom,solut gmbhmailtomaximlychevxplmcom,ref,lower case,sprint,kruse,hf,agil part,push,oliv,hrb html,lychev send,mnchen,gmbhmailtomaximlychevrdsoftwarecommailtomaximlychevrdsoftwarecom,rdsoftwar gmbhmailtomaximlychevrdsoftwarecommailtomaximlychevrdsoftwarecom,van der,denni,registergericht amtsgericht,rechtsform,beschrnkter,beschrnkter haftung,haftung,mit beschrnkter,gmbh rechtsform,design push,lead system,anna,tidstam anna,gtting,gtting denni,tidstam,plmg,koppi andrea,koppi,andreaskoppithermofishercom sent,html andreaskoppithermofishercom,subject dionex,andreaskoppithermofishercom,dionex
#
# # DITTEL:
#   . selected features: 27
#   . top features: fab,suffici,caus error,need get,seriou,get new,fail creat,kirillov wrote,expens,lebedev denisassanbaevrdsoftwarecom,amount,piec,user interfac,make new,denisassanbaevrdsoftwarecom gregori,recompil,case need,tuesday juli,us new,new connector,com,assembl pcb,mainli,assembl board,board assembl,histor,histor design
#
# # DM:
#   . selected features: 212
#   . top features: ag co,istemp,support dm,dm sp,pba draw,telecom,lescow,control,xplm solut,diod,drger vorschairm,vorschairm,dxdatabook entri,hilsen,venlig,venlig hilsen,alexei kirillov,isnew,isnew istemp,recipi pleas,regardsmaxim,hen krohn,agil plm,note draeger,regardsmaxim lychev,subbiah,subbiah venkatesh,confidenti inform,librarymerg,sebastian jemelka,cc ritter,volkmar subject,subject drger,venkatesh,tool,sent maxim,lychev xplm,hello maximw,lychev maxim,hen lebedev,uat,sheet,html andreasjemelkadraegercom,contain confidenti,norbert norbertzimmermanndraegercom,subject merger,ddraegerintegratedocinterfaceexelibintegratestartuprbin,senden,med,aw dm,projectdraeg,sollten sie,sebastian lebedev,schlicht peter,begemann marcu,andreasjemelkadraegercom sent,interfac,ihrem,sebastian cc,sync interfac,vertraulich informationen,dm projectdraeg,projectdraeg medic,cc zimmermann,agil,volkmarhussdraegercom cc,andov,hilsen volkmar,med venlig,regard med,dm integr,aufsichtsratschairman,aufsichtsratschairman supervisori,de aufsichtsratschairman,report writer,system html,norbertzimmermanndraegercom,senden sie,hu html,norbert subject,ihrem system,writer,dies nachricht,schlicht,amtsgerichtloc,amtsgerichtloc court,court lbeck,der gesellschaftregist,gesellschaftregist,gesellschaftregist offic,lbeck hrb,offic lbeck,global librari,die email,sender delet,sebastiankrohndraegercom,denabsend,andreasjemelkadraegercom,return email,partit,bitt dies,zimmermann,gabi,volkmar hu,au ihrem,record dies,handelsregistercommercialregist,handelsregistercommercialregist amtsgerichtloc,lbeck handelsregistercommercialregist,contractor,begemann,commun contain,mergertool,cloc,email au,email sein,informationen sollten,loeschen,loeschen sie,sein senden,seucg,draeger medic,sebastian extern,board stefan,regard volkmar,send krohn,fromyour,denabsend zurueck,derbeabsichtigt,derbeabsichtigt empfaeng,dies denabsend,empfaeng,empfaeng dieser,enthaelt,enthaelt vertraulich,nachricht enthaelt,nicht derbeabsichtigt,und loeschen,zurueck und,pleas return,andrea krohn,hu,zurueck,email sender,capgemini,inform theintend,medic version,gabrielefaberdraegercom cc,delet fromyour,fromyour record,cc faber,administr groupfydibohfspdltcnrecipientscnfaadcfddem,groupfydibohfspdltcnrecipientscnfaadcfddem,groupfydibohfspdltcnrecipientscnfaadcfddem send,cc jemelka,send faber,dm eedocinterfac,eedocinterfac,eedocinterfac problem,global,send huss,hello maximi,librari merger,gabriel gabrielefaberdraegercom,hen subject,volkmar cc,sebastian ritter,maximi,sandbox,dm save,draeger,sent lychev,dxdatabook,medic,pba,doc interfac,control sheet,zimmermann norbert,sebastian subject,drger,syncinterfac,regardsgabihtml,faber gabriel,ritter,jemelka andrea,lbeck,ritter hen,gabriel,norbert,jemelka,docinterfac,html gabrielefaberdraegercom,faber,huss volkmar,gabrielefaberdraegercom sent,hen,regard volkmarhtml,huss,merger tool,volkmarhtml,cc krohn,gabrielefaberdraegercom,html volkmarhussdraegercom,volkmarhussdraegercom sent,volkmar,merger,volkmarhussdraegercom,sebastian,krohn sebastian,krohn,subject dm,dm
#
# # DMS:
#   . selected features: 16
#   . top features: english,mh,document best,get new,projekt,copi project,einleiten,open eplan,dienstag oktob,assign new,okz,freitag juni,build data,compass,dm,psp
#
# # DOM:
#   . selected features: 16
#   . top features: cc herwig,orcad captur,scenario,virus,send lebedev,administr groupfydibohfspdltcnrecipientscnaeaebceafdsaschapogu,file instal,dsn,abil,licens file,set integr,id like,uk,anxp,regardssascha,domino
#
# # DRA:
#   . selected features: 22
#   . top features: artwork,hellomr,cpm,cadenc,subject drger,ascii file,insp,releas includ,chdlsnx,problem bei,drger,exe file,exe,collabor,draeger,dra,inspect,design collabor,chdlznx,safeti,mew,draeger safeti
#
# # DRAPER:
#   . selected features: 43
#   . top features: park,groupfydibohfspdltcnrecipientscnccaacfcacfbdpavelsozon sent,email pleas,proprietari,dx,send scott,solut inc,attach may,immedi destroy,mark caradonna,pleas immedi,sozonovski subject,pavel sozonovski,regardspavelhtml,cc mark,low,immedi notifi,contain proprietari,info info,pm scott,copi email,groupfydibohfspdltcnrecipientscnccaacfcacfbdpavelsozon send,clae cc,administr groupfydibohfspdltcnrecipientscnccaacfcacfbdpavelsozon,groupfydibohfspdltcnrecipientscnccaacfcacfbdpavelsozon,clae,info skip,mappedcharacterist,skip mappedcharacterist,hi scott,scott clae,scott,pm pavel,edx,bodi,enovia,edm,mentor edm,helg sadewass,sadewass,subject draper,helg,draper
#
# # DS:
#   . selected features: 41
#   . top features: immedi notifi,found creat,subject integr,push bom,complet project,integr issu,dialog box,herein,acad,project number,cell html,push,standard integr,line item,part store,iprinteracad,nic,administratorhtml,davi,davisstandard,davi standard,push pdf,dave stuart,jim subject,ds,autocad,subject ds,thompson nichola,thompsonsystem,cc cunningham,jim,thompson,nichola,stuart jim,stuart,cunningham dave,cunningham,html nthompsondavisstandardcom,dave,nthompsondavisstandardcom sent,nthompsondavisstandardcom
#
# # DXTOSNX:
#   . selected features: 61
#   . top features: svn rev,dorothe lebedev,martina wiethan,supportw,cc walter,digitaltest,extractor,rd svn,xdx,mentor expedit,mentor graphic,schemat,andrea walter,edif,martinawiethan,martinawiethan dorothe,walter martinawiethan,dear,use mentor,drawn,pin,dxdesign,net name,japan,creat duplic,xdx design,nailsasc,net,dx,heidenhain,mitsubishi,viewer,snxbnl,text size,vcc,clink qmanhtml,qmanhtml,pin name,ed,signal,version ee,dx design,clink,olaf,nail,produkt,manag clink,produkt manag,rohrbach softwar,softwar produkt,schemat viewer,rohrbach html,rohrbach,olafrohrbacherdigitaltestd,olaf rohrbach,olafrohrbacherdigitaltestd sent,html olafrohrbacherdigitaltestd,regard olaf,froniu,dxtosnx,dxsnx
#
# # ECTR:
#   . selected features: 81
#   . top features: capit,xdx,administr groupfydibohfspdltcnrecipientscncebcffaffaaebeatewilk,groupfydibohfspdltcnrecipientscncebcffaffaaebeatewilk,groupfydibohfspdltcnrecipientscncebcffaffaaebeatewilk sent,gerhard,qa,subject sap,administr groupfydibohfspdltcnrecipientscneaaccbaeaandreasbec,groupfydibohfspdltcnrecipientscneaaccbaeaandreasbec,groupfydibohfspdltcnrecipientscneaaccbaeaandreasbec sent,mentor xpedit,snip hello,plmecc,xdxdesign,hi support,firma,veracod,httpssupportwdfsapcorpsapsupportmessag,regardsbeatehtml,isv,strung,strung isv,ectr integr,ectr hello,dear expert,dsc,rc,subject ticket,engin control,supportxplmcom sent,ch,xad,snip dear,ectr version,expert,httpssupportxplmcomotrsindexplactionagentticketzoomticketid,httpssupportxplmcomotrsindexplactionagentticketzoomticketid otr,masterhtml,notif masterhtml,otr notif,ticket new,html supportxplmcom,ticket notif,ecad,otr,snip httpssupportxplmcomotrsindexplactionagentticketzoomticketid,ticket ecad,wrote snip,test execut,ectr releas,himmelsbach gerhard,aw ectr,ectrtest,altiumectr,ectr ecad,verbesserungplmhttpsjiradscsagnetbrowseplmimprov,himmelsbach,ectr test,ectr sap,regard snip,sapectr,notif,pq,interfac ecad,ectr ectr,support supportxplmcom,new ticket,snip,ticket,sap ectr,ecad sapectr,sapectr sap,supportxplmcom wrote,bugplmhttpsjiradscsagnetbrowseplmfix,sap support,ectr interfac,supportxplmcom,sap,subject ectr,ectr
#
# # EGO:
#   . selected features: 25
#   . top features: dezemb,jira issu,fresh,benefit,ich die,wrde,cc sven,kienzler eugen,rudolf knobloch,die stcklist,klau,gerad,lebedev deni,freitag mrz,walter cc,hr,nikolaeva maxim,euch,pleas download,cae hello,poc,issu alexej,dump avail,zuken,ego
#
# # EIS:
#   . selected features: 15
#   . top features: sent tuesday,march,admincaeconsultcom cc,svenraucaeconsultcom,alexejlebedev,sven pleas,denisassanbaevrdsoftwarecom,lychev sent,messag maxim,cc alexejlebedev,denisassanbaevrdsoftwarecom subject,design hello,svenraucaeconsultcom admincaeconsultcom,alexejlebedev dmitri,tuesday march
#
# # ELB:
#   . selected features: 21
#   . top features: sven pleas,attach best,task,thursday februari,kirillov gregori,workshop,thank sven,creat instal,along,lychev alexej,gmbhmailtomaximlychevrdsoftwarecom origin,helloalexej,gmbhgeschftsfhrer,svenrau mailtosvenraucaeconsultcom,helloalexej pleas,gmbhgeschftsfhrer sven,rau gmbhgeschftsfhrer,find document,wednesday januari,messag svenrau,januari maxim
#
# # ELE:
#   . selected features: 22
#   . top features: bestregard lidia,sent donnerstag,hello christophi,deutsch,prepar instal,nd,instal instal,found problem,problem occur,zw,select document,export pdf,renato hello,function work,updat histori,adopt,utf,donnerstag septemb,lidianikolaeva,psp,cabinet,public
#
# # EMR:
#   . selected features: 18
#   . top features: user abl,resend,line bom,bom line,integr need,report hi,isp,ara,integr licens,impact,cadenc,teamw,ara integr,emerson,sameer,cadenc integr,baji,corpin
#
# # EPDM:
#   . selected features: 118
#   . top features: cv,video,thanksbest,har,renato becker,critic issu,zhelokov,send pm,theindividu,may confidenti,attach intend,uk,dwg file,bori,coventri,simmat renato,theindividu entiti,use theindividu,relianc,one name,bridg,ribbon,andwal,england andwal,disclos copi,name recipi,nice dayborishtml,cabl,connector,beta,midland,midland england,offic riley,west midland,ltd,itii,itii pleas,dayborishtml,portfolio,portfolio manag,product portfolio,alexei nikolaeva,renato zhelokov,regard jerom,zhelokov bori,moor,sw,feinstein loui,verbos,josh,feinstein,swe api,ssa,krick,offic mobil,uk ltd,solidwork pcb,regardsbori,jerom subject,version swe,cc jerom,sweswpdm,england,karishmadcostadscom,fabien legrand,roux cc,henri,system uk,krick henri,dcosta karishma,html jeromemargetdscom,brouxtracesoftwarecom,tewzip,arnaud villion,dwg,jeromei,pdm connector,benjamin roux,marget cc,jeromemargetdscom sent,dassault system,roux benjamin,dcosta,iryna,regardsborishtml,fabien,sp releas,pm marget,sw pdm,epdm swe,karishma,vault,jeromemargetdscom,sp,addin,legrand,swpcb,api,solidwork,benjamin,villion,jerom cc,spr,dassault,arnaud,roux,swpdm,groupfydibohfspdltcnrecipientscnbadeefbcdfdbccboriszhelo send,administr groupfydibohfspdltcnrecipientscnbadeefbcdfdbccboriszhelo,groupfydibohfspdltcnrecipientscnbadeefbcdfdbccboriszhelo,jerom marget,pdm,marget jerom,subject epdm,marget,epdm,jerom,swe
#
# # ERBE:
#   . selected features: 17
#   . top features: posit number,dmitrymr,rudolf,knobloch,fehler bei,call ask,lychev subjectr,file best,integr mit,uwe,integratebat,refdes,theyhav,siegfri,klein,bae,erb
#
# # ERCO:
#   . selected features: 17
#   . top features: altium,class,pavel becker,synchron part,materi,chose,sap,teil,klass,dblib,insap,jennif,jennif cc,herz jennif,herz,subject erco,erco
#
# # EST:
#   . selected features: 18
#   . top features: go use,main problem,variant design,cae hello,reus,test result,retriev,terri,infor,mittwoch septemb,shortcut,recurs,plm client,alitum,infor plm,instal cae,est,reus design
#
# # EWZ:
#   . selected features: 46
#   . top features: sven,januari pm,rau subject,sent tuesday,variabl set,tuesday januari,liokumovich sent,storag area,pmto,gregori liokumovich,hello gregori,consult dorothe,liokumovich,cc sven,liokumovich cc,manag rdsoftwar,karlsruhegermani,karlsruhegermani offic,pdf log,liokumovich project,tuesday may,offic st,fax offic,dump best,regard gregori,storag,gregoryliokumovichrdsoftwarecom,gregori,httpwwwrdsoftwarecom,web page,httpwwwrdsoftwarecom origin,gmbhgablonzerstr,gmbhgablonzerstr karlsruhegermani,gregoryliokumovichrdsoftwarecom web,petersburg,st petersburg,page httpwwwrdsoftwarecom,dorothe wiethanmailtodorotheewiethancaeconsultcom,wiethanmailtodorotheewiethancaeconsultcom,wiethanmailtodorotheewiethancaeconsultcom sent,vista,font,pm gregori,subject ewz,ewz,anypdf
#
# # FAMECC:
#   . selected features: 16
#   . top features: engin base,perform test,project plan,uom,access test,qualiti,xplm connector,classif hello,copi content,simmat subject,file server,eb,proto,marco,soap,antonio
#
# # FESTO:
#   . selected features: 25
#   . top features: dmitrypleas find,save process,issu updat,system hello,brows,part new,precreat,windchil,flat,attach zip,dmitrya,product system,kirillovhtml,former,regardsdmitri kirillovhtml,send erik,instal packag,thorsten,ptc windchil,horn,erik horn,erik,cc erik,horn subject,festo
#
# # FILL:
#   . selected features: 14
#   . top features: profil instal,liokumovich subject,sql server,filtrat,updat profil,map metadata,field use,name name,teileart,fill integr,gaisbck,thomasgaisboeckfillcoat,fill,subject fill
#
# # FINCAD:
#   . selected features: 20
#   . top features: reconfigur,dump avail,europ,profil api,ccsvenraucaeconsultcom,ccsvenraucaeconsultcom subject,friday may,prio,lychev ccsvenraucaeconsultcom,like make,short webex,dump need,datum fri,alexej origin,betreff fwd,von sven,tuesday octob,may von,analys,meet requir
#
# # FRE:
#   . selected features: 18
#   . top features: rau subject,workshop,kirillov martina,send david,wr,pleas confirm,ever,date wed,dmitri kirillovmaxim,kirillovmaxim,kirillovmaxim lychev,theenviron,novemb dmitri,walter subject,dump custom,sonntag,martina pleas,pulsonix
#
# # FRECH:
#   . selected features: 24
#   . top features: relev,asepar,nikolaeva html,find detail,integr folder,aw integr,regardslidia nikolaeva,eplan instal,lidia send,weiter,punkt,unpack zip,stp,zugriff,zimmermann,thoma cc,instal instruct,lic,send zimmermann,zimmermann thoma,oskar,oskar frech,subject frech,frech
#
# # GLUTH:
#   . selected features: 19
#   . top features: grssen,martinawalterxplmcom,write back,problem bei,ootb releas,exist profil,lead system,brief,manufactur,seit,simmat dorothe,eplan valu,th octob,helmut,list valu,herstel,artikelabgleich,subject gluth,gluth
#
# # GROB:
#   . selected features: 26
#   . top features: interest,split,risk,offer,chapter,youpleas,that,phase,todmitri,todmitri kirillov,oktob,kirillov lidia,need estim,tier,thecustom,mittwoch oktob,freitag oktob,okay,renatosimmatcaeconsultcom,part bom,want start,renato von,idont,regard renato,cross,isto
#
# # GRUNDFOS:
#   . selected features: 124
#   . top features: upload sap,comparison,vi,sap,place,far see,lead,sort,critic error,subitem,sap bom,sign,refd,detect,version pad,pad logic,padsintegr,subassembl,bom comparison,ecm,bom sap,due,acc,parttyp,pad librari,ectr,backend,bom upload,start ectr,upload bom,synch,smd,comparison dialog,po,hold,modifi bom,supportecad cc,vintegr,chang note,bectr,bectr version,grundfo bectr,mechatron,place po,integr ectr,version grundfo,dk,lead bom,volum,stock,bom,upload,pad,ectr backend,bom hivers,mechatron direct,product mechatron,volum product,padssap,mobil email,ecad system,consult high,high volum,backend integr,ectr frontend,frontend ectr,versionsectr,versionsectr ectr,integr vectr,bom number,regard klau,direct mobil,bak ecad,hitest ectr,frontend,... html,smd bom,stock number,email kbakgrundfoscomgrundfo,kbakgrundfoscomgrundfo,kbakgrundfoscomgrundfo hold,system consult,vectr,...,wwwgrundfoscomhttpwwwgrundfoscom ...,denmark phone,phone wwwgrundfoscomhttpwwwgrundfoscom,denmark,bjerringbro denmark,due jensen,hold poul,jensen,jensen vej,poul,poul due,vej,vej dk,wwwgrundfoscomhttpwwwgrundfoscom,hitest,bjerringbro,dk bjerringbro,movi,klau,cc jakob,subject grundfo,klau bak,bak,christensen subject,christensen,raadik christensen,jakob raadik,raadik,hivers,hivers integr,jakob,sommer subject,sommer,cc gert,gert,gert sommer,html kbakgrundfoscom,grundfo,kbakgrundfoscom sent,kbakgrundfoscom
#
# # GRVE:
#   . selected features: 22
#   . top features: lebedevdenisassanbaevrdsoftwarecom gregori,build data,least,sent monday,dmitri originalmessag,mailtodmitrykirillovcaeconsultcom,wish,subjectr,problem bom,env,mailtodmitrykirillovcaeconsultcom sent,var,liokumovich subject,fromdmitrykirillovcaeconsultcom,fromdmitrykirillovcaeconsultcom mailtodmitrykirillovcaeconsultcom,lychev subjectr,webex best,ship new,wednesday juli,instal releas,would work,assembl item
#
# # HAR:
#   . selected features: 16
#   . top features: alexejlebedev gregori,wednesday march,md best,lychev lidianikolaeva,nothav,jan von,quot,updat issu,root caus,har,md,sr,charli,linux,certifi,harri
#
# # HDH:
#   . selected features: 47
#   . top features: ecirearel,ole error,dmitrykirillovxplmcom cc,geschftsfhrung,aufsichtsratsvorsitzend,christian,ti,ecirearel input,input par,work set,edbeci ecirearel,cmd,stromlaufplan ohn,geschftsfhrung manag,dmitryw problem,stromlaufplan,stephan,edbeci,ecaddesign document,eevx,regina,hildebrand regina,chairman,integr design,hildebrand,mr schlaipfer,checkoutlibrari,ecadlibrari,gnther,aw hdh,regardschristianhtml,schlaipfer,subject heidenhain,portenkirchn gnther,aloi,brugger aloi,ecaddesign,portenkirchn,html steinerheidenhaind,steiner christian,brugger,subject hdh,steinerheidenhaind sent,heidenhain,steinerheidenhaind,steiner,hdh
#
# # HER:
#   . selected features: 56
#   . top features: error search,un,pdm system,im anhang,au eplan,wiethan renato,version ship,manfr,morgen herr,guten morgen,ein,vorsitzend,sprecher,in,bernhard,synchronisieren,maschinenfabrik,tce,eplan releas,bet,evtl,beim,problem beim,rottweil,beck franzxav,alfon,alfon bet,erfllungsort gosheim,gerichtsstand rottweil,gosheim gerichtsstand,beck,erfllungsort,gerichtsstand,einleiten,elcad,florian cc,maschinenfabrik berthold,graiss manfr,gosheim,html florianquarleiterhermled,agia,agia florian,herml agia,freundlichen grenmaschinenfabrik,grenmaschinenfabrik,grenmaschinenfabrik berthold,florianquarleiterhermled sent,beim einleiten,quarleit florian,graiss,florian,florianquarleiterhermled,berthold,berthold herml,quarleit,herml
#
# # HOL:
#   . selected features: 36
#   . top features: gmbhmailtomaximlychevxplmcommailtomaximlychevxplmcomsubmit boxhttpsftapixplmcomsubmitmaximlychevxplmcom,cip,cipe,dmitrypleas see,claesxplm,claesxplm solut,batch sync,ap,blockedhttpwwwxplmcomhttpwwwxplmcomscottclaesxplmcommobil,batch file,claeshtml,incwwwxplmcomhttpwwwxplmcom,solut incwwwxplmcomhttpwwwxplmcom,regardsscott claesxplm,hresult error,dupgroupuhfeatur,jeff,incwwwxplmcomhttpwwwxplmcom blockedhttpwwwxplmcomhttpwwwxplmcomscottclaesxplmcommobil,thank regard,tmp part,send kirillov,part statu,cc scott,batch,lmgrd,ole,achath,gopu,gopu achath,standarderror,caecon,mfg,agil part,jeffiemaedacom,mfg part,holog
#
# # HOLCIM:
#   . selected features: 13
#   . top features: hello sir,resend,wewould,originalmessag,previou releas,octob,wednesday octob,vom,sentwednesday,elektrisch,iec,eb,holcim
#
# # HP:
#   . selected features: 17
#   . top features: cycl,tuesday octob,prototyp,may von,eco,admincaeconsultcom alexej,liokumovich cc,board fabric,dmitrykirillov subject,sentthursday,integr agil,build data,run integr,problem run,integr cadenc,hp,thoon
#
# # HUI:
#   . selected features: 52
#   . top features: cabinet,simmat cc,groet,vriendelijk groet,groet kind,met,partslist,zw file,netherlandsphon,report hi,last modifi,hyperlink,email attach,electr part,met vriendelijk,vriendelijk,modifi date,hh,wtpart,content email,locat,equip,regard met,max,ron,kind regardsmax,regardsmax,janssen,janssen thoma,ozen,ozen mehmet,schemk,schemk max,danni,subject hui,suijker danni,mehmet,html mschemkeshuismannlcom,suijker,mschemkeshuismannlcom sent,huisman,mschemkeshuismannlcom,html rhalvehuismannlcom,aad,vonk aad,richard,vonk,rhalvehuismannlcom sent,hui,rhalvehuismannlcom,halv richard,halv
#
# # HWEBER:
#   . selected features: 17
#   . top features: itshould,nikolaeva dmitri,html renatosimmatxplmcom,renatosimmatxplmcom sent,regardsstefan,question integr,enter valu,test licens,creat anew,maschinenfabrik,fischer,part profil,vorher,weber,han,subject hweber,hweber
#
# # HYDR:
#   . selected features: 21
#   . top features: cp,kopi,date tue,donnerstag juli,mailtoadmincaeconsultcom,raoul marku,fwd aw,eugenkienzl,dmitrykirillovcaeconsultcommailtodmitrykirillovcaeconsultcom,dmitrykirillovcaeconsultcommailtodmitrykirillovcaeconsultcom sent,raoul,date wed,von dmitri,phase,wed,april dmitri,set posit,rau mailtoadmincaeconsultcom,chnage,antwort,mittwoch juni
#
# # IHC:
#   . selected features: 38
#   . top features: use copi,check releas,problem eplan,integratemd,look docbaugrupp,print retain,read print,docbaugrupp found,skype,messag attach,group,itembaugrupp log,group pdf,bestregard lidia,part link,open dialog,link part,documentdocbaugrupp,documentdocbaugrupp log,process documentdocbaugrupp,log process,workflow state,partlist,quiet,batch mode,log docbaugrupp,itembaugrupp,email messag,itembaugruppeebom,document docbaugrupp,page properti,docbaugrupp log,remco,checkin group,docbaugrupp,lesha,ihc pc,ihc
#
# # IKA:
#   . selected features: 20
#   . top features: alexand kaufmann,contact,version altium,cc alexand,simmat maxim,na,cdb,daniel,altium shipment,index,cimdb,pm renato,fi,regardsandrea,rainer,fritz,kruse,daniel kruse,emil,ika
#
# # IMA:
#   . selected features: 39
#   . top features: ergebni,error updat,gibt es,gre,immer noch,sehr,rupietta,gibt,christoph,werden die,geehrt,der artikel,otto,cc christoph,christoph rupietta,sehr geehrt,damen,damen und,geehrt damen,rupietta subject,gre best,freundlich,elcad,ima aw,aw ima,ima wg,greotto schmidthtml,schmidt otto,ima ima,greotto,elcad problem,schmidthtml,schmidt,ima elcad,html ottoschmidtimad,ottoschmidtimad sent,ottoschmidtimad,subject ima,ima
#
# # INF:
#   . selected features: 35
#   . top features: data sourc,oracl,odbc,databas use,manufactur data,jennif cc,part document,sql databas,best regardshtml,timefram,dev,design data,instal custom,signal,erik,erik horn,assumpt,bare,herebest,categori,pierron,pierron jennif,rest api,kirillovhtml,horn cc,done use,horn sent,data manag,horn,regardsdmitri kirillovhtml,administr groupfydibohfspdltcnrecipientscnefccdcdbecafcderik,groupfydibohfspdltcnrecipientscnefccdcdbecafcderik,groupfydibohfspdltcnrecipientscnefccdcdbecafcderik horn,bare board,last modifi
#
# # INSP:
#   . selected features: 32
#   . top features: design collabor,hello sven,petersburg russia,ref,collabor,answer interleav,znx,gregori,sexau,demo hello,hello gregori,dont rememb,blue,gregori pleas,sven pleas,emailgregoryliokumovichrdsoftwarecom,emailgregoryliokumovichrdsoftwarecom web,russia emailgregoryliokumovichrdsoftwarecom,answer attach,metrotech,physic,gregori liokumovichsvenraucaeconsultcom,layer,find answer,browser,highlight,unresolv,fu,fu unresolv,bnx,insp,inspect
#
# # IPI:
#   . selected features: 22
#   . top features: helpdesk,step step,licens problem,georg,administrativegroupcnrecipientscndmitrykirillov send,esli,new server,room,ahead,delta,ordsoftwareoufirst,account,embachdeeg,veroniqu,design ara,exchang server,send dec,vmware,lync,administrativegroupcnrecipientscnalexejlebedev,ordsoftwareoufirst administrativegroupcnrecipientscnalexejlebedev,transmiss
#
# # ISG:
#   . selected features: 32
#   . top features: appoint,lose,via ftapi,use configur,send sep,gotomeet,caradonnadirector,caradonnadirector sale,sale busi,wednesday april,mark kirillov,busi develop,variant assembl,mark,design variant,caradonna,pm caradonna,configur hi,mike,administr groupfydibohfspdltcnrecipientscnbcdaadfecfmarkcarado,groupfydibohfspdltcnrecipientscnbcdaadfecfmarkcarado,groupfydibohfspdltcnrecipientscnbcdaadfecfmarkcarado sent,caradonna mark,ryan,run save,lloyd,ryan lloyd,iom,mark cc,send caradonna,isg,insitu
#
# # ISP:
#   . selected features: 19
#   . top features: instal pc,helloalexej pleas,pretti,alexand lebedev,pair,starter,simmat dmitri,specif hello,pleas advis,domino,bom compar,esli,starter packag,andrea wiethan,ootb releas,eplan teamcent,dienstag juni,isp,iz
#
# # ITEL:
#   . selected features: 18
#   . top features: assembl data,date wed,ecad design,data upload,pcb file,ftp account,check file,sent alexej,pool,tom,item ad,sdk,java client,bom error,ftp site,fatal,fatal error,edt
#
# # JUNKER:
#   . selected features: 44
#   . top features: cc renato,renato simmat,alexei lebedevalexeilebedevxplmcom,lebedevalexeilebedevxplmcom,eplan,html renatosimmatxplmcom,renatosimmatxplmcom sent,simmat renatosimmatxplmcom,subitem,epl,eplan nach,marku,simmat maxim,kai,sap eplan,regardspavel sozonovskyhtml,sozonovskyhtml,updat sap,bapi,administr groupfydibohfspdltcnrecipientscnalexei,groupfydibohfspdltcnrecipientscnalexei,groupfydibohfspdltcnrecipientscnalexei lebedev,kai pankrath,pankrath,sozonovski sent,sozonovski send,jrgen,sap connector,sap,lehmann,html pavel,lychev renato,marku cc,aw junker,junker sap,bischler,bischler jrgen,gewerk,eplan sap,markusgaesslerjunkerd,gssler marku,gssler,subject junker,junker
#
# # KAL:
#   . selected features: 13
#   . top features: interg,complet log,hello alexej,regard lidia,sub,projektadministr caeconsult,samstag,let meknow,meknow,okz,admincaeconsultcom subject,freitag februar,kallfass
#
# # KGS:
#   . selected features: 29
#   . top features: ergebni,meet hallo,administr groupfydibohfspdltcnrecipientscnffbebbccddeachristophr,groupfydibohfspdltcnrecipientscnffbebbccddeachristophr,groupfydibohfspdltcnrecipientscnffbebbccddeachristophr sent,gotomeet,au dem,use function,jar,christophrupiettaxplmcom,pm christoph,best regardschristoph,regardschristoph,nikolaeva lidianikolaevaxplmcom,itemtyp,releas custom,testprojekt,rupietta christophrupiettaxplmcom,dem meet,amol,rac,doppelt,keller,function open,almin,jabandz almin,jabandz,kg,subject kg
#
# # KOIKE:
#   . selected features: 22
#   . top features: part must,hello renatoi,autocad electr,lidia kirillov,subassembl,instal xplm,download portal,subject demo,tri import,innov part,edalibrari,temporari licens,file test,tri set,xplm licens,string,statu updat,new field,jim,dmitri caradonna,todaybest,suggest use
#
# # KOL:
#   . selected features: 23
#   . top features: steffen,get licens,renato hello,licens softwar,server hello,dorothe simmat,renato walter,hello lidiaher,konnt,com,profil integr,dmitri nikolaeva,pdf creation,administr groupfydibohfspdltcnrecipientscnfcdacdeaefafaa,groupfydibohfspdltcnrecipientscnfcdacdeaefafaa,administr groupfydibohfspdltcnrecipientscnfbbabbeeefcacdl,groupfydibohfspdltcnrecipientscnfbbabbeeefcacdl,pleas review,groupfydibohfspdltcnrecipientscnfcdacdeaefafaa send,groupfydibohfspdltcnrecipientscnfbbabbeeefcacdl send,koller,ecscad,kol
#
# # KUKA:
#   . selected features: 30
#   . top features: document need,regardsi,attribut map,neuanlag,store,notat,se,kirillov alexei,txt file,procedur,cc beat,part creation,beat wilk,wei,configur attribut,decim,pavelsozonovski,librari map,beatewilkexplmcommailtobeatewilkexplmcom,intdeclar,decimaldeclar,marioweisskukacom,groupindex,varchardeclar,store procedur,weiss,subject kuka,weiss mario,mario,kuka
#
# # KVH:
#   . selected features: 20
#   . top features: effort,administr groupfydibohfspdltcnrecipientscndfcabbaecfaedca,groupfydibohfspdltcnrecipientscndfcabbaecfaedca,groupfydibohfspdltcnrecipientscndfcabbaecfaedca sent,respect,infor plm,need estim,resolv issu,need also,design integr,begin,plm integr,instal custom,assumpt,add addit,estim effort,exampl design,also provid,custom test,design librari
#
# # LAB:
#   . selected features: 37
#   . top features: special charact,usernam password,immedi contact,persist,youar,subject xplm,youar intend,go product,voltag,attach sole,filtrat,use theintend,replyemail,clae scott,part statu,troubleshoot,cant find,ricardo,ime subject,ime,jeff ime,jeff,audio,sameer,vendor,log configur,cc clae,contain field,look log,misc cipe,ic,databas contain,cipe,misc,lab,audio misc,cipe databas
#
# # LAEMPE:
#   . selected features: 27
#   . top features: creat materi,insap,lebedev renato,sap connector,wb,lang,sap,html pavel,sozonovski send,sap eplan,bapi,carsten,extens,manufactur,kai,lm,rs,fieldcollect,manufactur data,kai pankrath,pankrath,valuevalu,field field,valuevalu field,httpcaeserverbrowselaemp httpcaeserverbrowselaemp,httpcaeserverbrowselaemp,laemp
#
# # LANDISGYR:
#   . selected features: 17
#   . top features: check box,solut gmbh,want us,pleaselet,cet,davi,dimitri,hi scott,regardsscott,eric,dblib,output file,mentor pad,discuss last,altium librari,xec,lg
#
# # LEAR:
#   . selected features: 15
#   . top features: global librari,usual,cover,dxdatabook,global,wire,pm maxim,publish part,delta,ms access,analysi,region,wednesday may,standard function,sem
#
# # LEGO:
#   . selected features: 26
#   . top features: subject question,wonder,deriv data,suffix,marc hutsch,xml,frank,horn subject,client instal,mechatron,pcba,text file,file gener,filterdefault,alexeipleas,duplic,meet next,guysi,creat duplic,oper system,thecurr,shouldnt,hi guysi,instal file,deriv,deriv file
#
# # LEO:
#   . selected features: 23
# ...
#
# # TBN:
#   . selected features: 98
#   . top features: homepag,dxdesign,leiter,assembl plot,regard maximlychev,theconfigur,regard maxim,board assembl,lychev rdsoftwar,sven origin,tbn sp,messag subject,lychev alexei,handelsregist amtsgericht,tbn ba,januari maxim,vorstand,maximlychev rdsoftwar,rdsoftwar gmbh,gmbh mailtomaximlychevrdsoftwarecom,rdsoftwar,aufsichtsrat,pm maxim,mech,mailtomaximlychevrdsoftwarecom,tomaxim,jeder,filerecord,tomaxim lychev,postfach,hello sven,gru,hello maxim,fon,fon fax,cadstar librari,ee,renner,renner vorsitzend,de aufsichtsrat,der adressat,confidenti intend,gestattet confidenti,vertraulichkeitshinwei,nur fr,die person,mit freundlichem,aufsichtsrat gunther,news auf,sind nur,freundlichem,fax wwwthebend,ag postfach,postfach haigerloch,adressiert,bermittelt,bermittelt anhang,bitt unverzglich,jeder bermittelt,person bestimmt,seiner,sie adressiert,und jeder,und seiner,und sind,unverzglich,unverzglich den,weitergab und,wwwthebend vertraulichkeitshinwei,plot,amtsgericht stuttgart,tce,gunther,sven,haigerloch fon,hohenbergstra haigerloch,ag,freundlichem gru,cadstar,haigerloch hohenbergstra,hohenbergstra,email und,mllerreis andrea,mr muellerreis,andrea theben,wwwthebend,mllerreis,gru andrea,andreasmuellerreiserthebend,haigerloch,andrea muellerreis,subject theben,theben ag,muellerreis,tbn theben,subject tbn,tbn,theben
#
# # TEST:
#   . selected features: 18
#   . top features: chto,flag,lost,jira,pictur,vse,news,sent pavel,bi,pavelsozonovskyxplmcom,sent alexej,outlook,html ordsoftwareoufirst,ordsoftwareoufirst,administrativegroupcnrecipientscndmitrykirillov,ordsoftwareoufirst administrativegroupcnrecipientscndmitrykirillov,subject test,int
#
# # TESTIT:
#   . selected features: 46
#   . top features: hostidani,origin specif,tomaxim,hostidani featur,tomaxim lychev,licens file,rohrbach html,found design,manag rdsoftwar,olaf,schematicsappl,te,net,pin,pool,mbh,japan,html olafrohrbacherdigitaltestd,mitsubishi,expert,snxbnl,regard olaf,olafrohrbacherdigitaltestd sent,nailsasc,ustidnr vatidno,uncount,net name,extractor,olaf rohrbach,rohrbach,olafrohrbacherdigitaltestd,boctor,director ute,lorenzstra,ute,ute boctor,vatidno,vatidno de,httinger,nail,fabmast,digitaltest,dde,highlight,ae,testit
#
# # THO:
#   . selected features: 17
#   . top features: al,fri,sent freitag,draw,date fri,rau mailtoadmincaeconsultcom,wewil,thank sven,frame,project file,schemat draw,draw frame,pay,updat project,chang order,freitag januar,project close
#
# # THY:
#   . selected features: 53
#   . top features: gren,thoma,antwort,sent lidia,freundlichen gren,set integr,thoma subject,eplan eplan,integrateschnittstel,fault,plm data,workflow,eplan,gren best,antwort aw,metaplot,elk,system hello,integr tc,bct,test eplan,thyssenkrupp,udo,stefan,ell,regardsdipl,abschlieen,tc,mr weber,weber html,kstrebelbcttechnologycom,aw thi,best regardsdipl,regardsthoma,stefan weber,thomasboelkethyssenkruppcom,best regardsthoma,tkf,hartmann moritz,ing,moritz,weber stefan,regardsdipl ing,html stefanweberthyssenkruppcom,stefanweberthyssenkruppcom sent,stefanweberthyssenkruppcom,ing stefan,blke thoma,subject thi,blke,weber,hartmann,thi
#
# # TKP:
#   . selected features: 28
#   . top features: boxhttpsftapixplmcomsubmitmaximlychevxplmcomhtml,administr groupfydibohfspdltcnrecipientscncaaefcaaefmaximlych,groupfydibohfspdltcnrecipientscncaaefcaaefmaximlych,groupfydibohfspdltcnrecipientscncaaefcaaefmaximlych send,intern name,kaufmann alexand,lgv,collect log,sp batch,part batch,batch sync,oracl,batch,alexand subject,configur test,part altium,mask,gmbhmailtomaximlychevxplmcommailtomaximlychevxplmcomsubmit boxhttpsftapixplmcomsubmitmaximlychevxplmcomhtml,cid,altium db,sascha,altium databas,thyssenkrupp,xenia risti,xenia,risti,subject tkp,tkp
#
# # TURCK:
#   . selected features: 161
#   . top features: kg,de inhalt,partassysmd,connectionlog remov,benachrichtigen,bitt benachrichtigen,log refd,read articl,plmclient,wichtig hinwei,finish log,propertieslog read,executionlog,modul executionlog,articl propertieslog,mit,fabric,co,registergericht regist,build project,empfnger bestimmt,close connectionlog,connectionlog,clean modul,regard html,benachrichtigen sie,michael betreff,hallo,executionlog close,refd tp,freundlichen,eciinsrelerr,regard ia,distributor,bestimmt sollten,court amtsgericht,den empfnger,ein kenntnisnahm,ge,ge werner,geschtzt oder,haft ge,hinwei dies,nutzung de,sonstig nutzung,iserlohn,board fabric,haben ist,hinwei,contractorslog,contractorslog read,read site,site contractorslog,docbestueckungsdatenbot,content hereof,error herebi,hereof,interfacegert werner,gmbh co,amtsgericht iserlohn,betrieb,busi secret,contain trade,die empfangen,empfangen,enthlt betrieb,haft,iserlohn hra,ist ihnen,kg per,per haft,trade busi,untersagt,untersagt bitt,weitergab oder,dimitryi,mr juergensmey,gren,datasheet,von der,freundlichen gren,foundlog,wwwturckcom von,interfacegert,layoutkonstrukt interfacegert,jrgensmey layoutkonstrukt,co kg,search plmlog,ceslogfilesconsdefloglog ceslogfilesconsdefloglog,ceslogfilesconsdefloglog,vandecrommert gerri,vandecrommert,personslog refresh,wwwturckcom,michael mit,plmlog,gerri,bom layout,modellog look,modellog,modul modellog,sonstig,gren best,foundlog read,halver tel,mit freundlichen,personslog,read personslog,oder sonstig,michael jrgensmeyerentwicklung,entrylog,entrylog read,histori entrylog,tusa,juergensmey,refresh modul,carsten,dmitrywir,read histori,layoutkonstrukt,regard rdiger,rdiger subject,beierfeld,rdiger vom,thorsten,goethestr halver,turck turck,goethestr,kg goethestr,michael subject,michael jrgensmey,aw turck,bkenkamp thorsten,fiebig,werner,halver,bkenkamp,turck gmbh,vom,brock rdiger,carstenfiebigturckcom,carstenfiebigturckcom sent,html carstenfiebigturckcom,werner turck,regard michael,html ruedigervombrocketurckcom,rdiger,ruedigervombrocketurckcom,ruedigervombrocketurckcom sent,hybrid,html michaeljuergensmeyerturckcom,michaeljuergensmeyerturckcom sent,cc jrgensmey,brock,vom brock,subject turck,michael,michaeljuergensmeyerturckcom,jrgensmey michael,jrgensmey,turck
#
# # UEC:
#   . selected features: 44
#   . top features: httpwwwrdsoftwarecom,pm gregori,web page,liokumovich sent,page httpwwwrdsoftwarecom,sch pcb,vpn connect,gregori liokumovich,fax mobil,sven sven,gregoryliokumovichrdsoftwarecom,liokumovich,karlsruhegermani,karlsruhegermani offic,golden design,integr test,vpn,fax offic,closer,regard gregori,gregoryliokumovichrdsoftwarecom web,dmitri kirillovsubject,po box,gregori pleas,hello gregori,gablonzerstr,gablonzerstr karlsruhegermani,gmbh gablonzerstr,cadstar librari,email gregoryliokumovichrdsoftwarecom,golden,mount,ltd,gregori,hous,offic fax,physic,cadstar,system manag,davi,pedro,south,south africa,uec
#
# # VAT:
#   . selected features: 25
#   . top features: nado,nikolaeva lidianikolaevaxplmcom,test result,flexlm,hello christophi,renato pleas,chang made,send log,administr groupfydibohfspdltcnrecipientscneaacbffdc,groupfydibohfspdltcnrecipientscneaacbffdc,groupfydibohfspdltcnrecipientscneaacbffdc sent,lizenz,dmitri simmat,find comment,save open,search dialog,elcad releas,nov supportecad,startet,function save,alexeilebedevxplmcom cc,first draft,dialog save,vat,vattenfal
#
# # VB:
#   . selected features: 30
#   . top features: file log,extractor,issu best,server use,look good,log see,onto,mentor expedit,xdx,pool,schemat viewer,dbg,olaf rohrbach,nailsasc,attach mail,regard olaf,nail,xdx design,heidenhain,buy,bnl,olafrohrbacherdigitaltestd,mentor vx,olafrohrbacherdigitaltestd sent,html olafrohrbacherdigitaltestd,rohrbach html,rohrbach,mr rohrbach,snx,vbsnx
#
# # VIT:
#   . selected features: 20
#   . top features: document releas,sommer,eplan problem,interfac hello,anpassung,rupietta cc,releas test,send jan,jan,section,frank,andr,total,daniel,integrateact,menuid,vitron,vit,babin,jan daniel
#
# # VMI:
#   . selected features: 23
#   . top features: bom updat,profil eplan,test server,nikolaeva html,part select,vriendelijk,synchronis,regardslidia nikolaeva,bom plm,kind,make pdf,kind regard,regardsstefan,cadpdm,vri,kind regardsstefan,html smoonsvmigroupcom,smoonsvmigroupcom sent,rdekensvmigroupcom,smoonsvmigroupcom,deken,subject vmi,vmi
#
# # VOS:
#   . selected features: 28
#   . top features: hello lidiaher,schnittstel,okz,elcad,eintrg,christoph,christophhtml,akz,alog,christoph cc,hello christophw,regardslidia html,partsubassi log,partsubassi,refresh partsubassi,pm rupietta,stl,juergen,eb,vo vossloh,kroppen juergen,engin base,kroppen,vossloh,jansen,kiep,subject vo,vo
#
# # VRAIL:
#   . selected features: 20
#   . top features: zip archiv,relat file,fehler bei,steffen,sent sep,bertrag,von eplan,attachedhtml,archiv attachedhtml,eplan nach,pf,part get,bertragung,bei bertragung,bertragung von,ronni,vossloh,vrail,rail,vossloh rail
#
# # VSMN:
#   . selected features: 15
#   . top features: alexej lebedevdenisassanbaevrdsoftwarecom,lebedevdenisassanbaevrdsoftwarecom,messag maxim,rau cc,iec,lebedev sent,regard frank,pad,orcad ci,tce,pad librari,oracl,symbol librari,ci,viessmann
#
# # VT:
#   . selected features: 29
#   . top features: dorotheewiethanxplmcom,ovington dmitri,cc paul,attach current,inform regard,wiethan subject,michael,htmlhello,fax von,lychev send,kienzler dorothe,question need,paul,dienstag septemb,ovington alexei,mannheim hra,train,walterxplm,walterxplm solut,ovington,invoic,paul ovington,amtsgericht mannheim,septemb maxim,integr specif,maier,vincotech,drmaier,css
#
# # WALD:
#   . selected features: 25
#   . top features: new problem,origin file,pavel,found reason,ecn,ickelheim,ectr client,beschreibung,administr groupfydibohfspdltcnrecipientscncaaefcaaefmaximlych,groupfydibohfspdltcnrecipientscncaaefcaaefmaximlych,sozonovski pavel,groupfydibohfspdltcnrecipientscncaaefcaaefmaximlych send,send beat,ralf,dim,open origin,pulsonix design,matstatu,pulsonix,send mbaermannwaldmanncom,mbaermannwaldmanncom cc,mbaermannwaldmanncom,waldmann,subject wald,wald
#
# # WASHTEC:
#   . selected features: 25
#   . top features: mit integr,profil,integr instal,attach patch,integr fehler,send mar,xplm integr,kaufman,bei,eplan interfac,pdf document,record pdf,alexand kaufman,administr groupfydibohfspdltcnrecipientscnfeacbecfccad,groupfydibohfspdltcnrecipientscnfeacbecfccad,groupfydibohfspdltcnrecipientscnfeacbecfccad send,zeichnung,assum,helmut,profil bei,bei washtec,helmut assum,washtec profil,subject washtec,washtec
#
# # WERMA:
#   . selected features: 25
#   . top features: pm beat,send beat,innovationdocu,nowbest,beat,hello dmitryattach,variant name,revis document,problem caus,plant,ectr connector,wilk subject,work directori,th octob,cideon,wilk cc,beat wilk,beateth,lebedev pavel,docinno,hello beateth,materi number,dirk,subject werma,werma
#
# # WILO:
#   . selected features: 35
#   . top features: gru,regard html,part list,wilk beat,pdfa,voigt,plant,freundlichem gru,freundlichem,werk,stephan,subvers,stamp,msg,cc wilk,gru best,cnv,tht,beat subject,smd,convert msg,strrd,strrd convert,pcba tht,ppt,benjamin,ep,hw,benjamineilebrechtwilocom,benjamineilebrechtwilocom sent,html benjamineilebrechtwilocom,eilebrecht benjamin,eilebrecht,subject wilo,wilo
#
# # WTT:
#   . selected features: 34
#   . top features: issu tri,dmitri cc,server integr,dmitryw,administr groupfydibohfspdltcnrecipientscndimitri,groupfydibohfspdltcnrecipientscndimitri,groupfydibohfspdltcnrecipientscndimitri kirillov,kirillov send,may,subject integr,pm kirillov,catalog,profil sp,item number,famili,subject profil,electr,tri releas,autocad,releas bom,autocad electr,wayn,frock jason,wayn trail,trail,mayhtml,html zacharymaywaynetrailcom,zach,subject wtt,wtt,zacharymaywaynetrailcom sent,frock,jason,zacharymaywaynetrailcom
#
# # WWERK:
#   . selected features: 22
#   . top features: upgrad integr,html lidia,version instal,save project,walter eugen,made chang,onlin meet,make webex,lidia subject,send renato,ship new,sent nikolaeva,possibl make,protocol,bearbeiten,integr dialog,open integr,fehlend,mebest,pc hello,upgrad profil,project project
#
# # XPLM:
#   . selected features: 16
#   . top features: rs,windchil server,ml,phase,itri,windchil,tt,ln,profession,stop error,jan,integr pad,particip,respond,pi integr,bank
#
# # ZEISS:
#   . selected features: 138
#   . top features: sozonovski subject,kirillov pavel,matthia,beat,pm beat,wilk,wilk subject,sozonovski,dtype,wilk cc,list hello,ecn,sec,dirti,el,regardspavel,supervisori,supervisori board,document number,pavel,groupfydibohfspdltcnrecipientscnccaacfcacfbdpavelsozon send,thank youbest,roh,pavel sozonovski,pdfa,marku,dipl,mller,characterist,groupfydibohfspdltcnrecipientscnccaacfcacfbdpavelsozon sent,xpup,bom transfer,dirti flag,cc beat,vat,reg,beat wilk,regardsdipl,administr groupfydibohfspdltcnrecipientscnccaacfcacfbdpavelsozon,groupfydibohfspdltcnrecipientscnccaacfcacfbdpavelsozon,germani phone,hello pavel,fpr document,dr karl,ulm,bestl,bestl marku,ulm hrb,sozonovski cc,mueller,pm pavel,fum,de html,guido,agcarl,agcarl zeisspromenad,jena germani,olafhollingerzeisscommailtoolafhollingerzeisscomwwwzeisscomhttpwwwzeisscom,olafhollingerzeisscommailtoolafhollingerzeisscomwwwzeisscomhttpwwwzeisscom carl,phone olafhollingerzeisscommailtoolafhollingerzeisscomwwwzeisscomhttpwwwzeisscom,zeiss agcarl,zeisspromenad,zeisspromenad jena,presid,dieter,ceodr matthia,dieter kurzboard,kurzboard,kurzboard manag,lamprecht presid,manag dr,board dr,olaf cc,busi servic,electron sbieej,hollingercad electron,sbieej,sbieej busi,agheadquart,agheadquart oberkochen,ceodr,germanychairman,germanychairman supervisori,hrb vat,jena,marku webercommerci,oberkochen germanychairman,presid ceodr,reg de,regist ulm,vat reg,webercommerci,webercommerci regist,zeiss agheadquart,mueller guido,infrastructurecarl,infrastructurecarl zeiss,servic infrastructurecarl,carl,carl zeiss,fpr,christian mller,dr christian,jochen peterdr,peterdr,peterdr marku,dr dieter,pm holling,dipl olaf,holling dipl,hollingercad,olaf holling,olaf hollingercad,dr jochen,dr ludwin,jochen,karl lamprecht,lamprecht,ludwin,ludwin monz,matthia metz,metz,metz dr,mller dr,monz,monz dr,oberkochen,regardsdipl olaf,olaf,holling olaf,html olafhollingerzeisscom,olafhollingerzeisscom sent,olafhollingerzeisscom,pulsonix,holling,dr,subject zeiss,zeiss
#
# # ZEP:
#   . selected features: 24
#   . top features: need time,send jan,administr groupfydibohfspdltcnrecipientscnffbebbccddeachristophr,groupfydibohfspdltcnrecipientscnffbebbccddeachristophr,groupfydibohfspdltcnrecipientscnffbebbccddeachristophr sent,bentigt,pm rupietta,timei,ini,thatth,version sp,lmgrd start,zw,eplan updat,eplan version,durch den,ndf,consol,document use,hide,updat auf,harder,zep,zeppelin
#
# # ZF:
#   . selected features: 17
#   . top features: config,starter packag,eplan integr,nikolaeva subject,book,hi dmitryw,groupfydibohfspdltcnrecipientscncbcacfafdcccefeffdmitrykiri sent,vrdsecadteam,eplan updat,updat version,dmitryfor,ap,thanksbest,maier,get order,pm lidia,integr xplm
#
# # ZSA:
#   . selected features: 28
#   . top features: problem resolv,vpn,januar,rolfpfen,karl wachtel,mittwoch januar,geschftsfhrer karl,wachtel rolfpfen,licens valid,address,rolfpfen sitz,registergericht freiburg,martina martina,winkler,pc,dn,ip,smtp,ip address,mxinfoenergoru,tobia,winkler tobia,januar dmitri,vmware,dongl,radmin,subject zsa,zsa
#
# # ZSYS:
#   . selected features: 2
#   . top features: id,id id
#
# # ZZZM:
#   . selected features: 39
#   . top features: regardsdmitryhtml,spent time,enter,dorothe cc,googl,pr,xplmordermanag,spent,denisassanbaevrdsoftwarecom subject,walter martina,deni,ordsoftwareoufirst,assanbaev,wiethan dorothe,html ordsoftwareoufirst,wb,deni assanbaev,denisassanbaevrdsoftwarecom,patrick,work hour,alexeilebedevrdsoftwarecom,martinapleas,martinapleas find,administrativegroupcnrecipientscndmitrykirillov,ordsoftwareoufirst administrativegroupcnrecipientscndmitrykirillov,administrativegroupcnrecipientscndmitrykirillov send,ap,sv,martina cc,pm walter,sv integr,tt,npdi,hour,zzzm npdi,npdi report,zzzm project,subject zzzm,zzzm

# %%
vectorizer = feature_extraction.text.TfidfVectorizer(vocabulary=X_names)
vectorizer.fit(corpus)
X_train = vectorizer.transform(corpus)
dic_vocabulary = vectorizer.vocabulary_

# %%
X_train.shape
# Out:
# (5755, 5164)

# %%
# naive bayes classifier

# %%
classifier = naive_bayes.MultinomialNB()

# %%
X_test = dtf_test["text_clean"].values

# %%
## pipeline
model = pipeline.Pipeline([("vectorizer", vectorizer),  
                           ("classifier", classifier)])
## train classifier
model["classifier"].fit(X_train, y_train)
## test

predicted = model.predict(X_test)
predicted_prob = model.predict_proba(X_test)

# %%
## Accuracy, Precision, Recall
accuracy = metrics.accuracy_score(y_test, predicted)

print("Accuracy:",  round(accuracy,2))

print("Detail:")
print(metrics.classification_report(y_test, predicted))
# Out:
# Accuracy: 0.49
# Detail:
# C:\Users\Elena\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   average_options = (None, 'micro', 'macro', 'weighted', 'samples')
#                precision    recall  f1-score   support
#
#           ACH       1.00      0.23      0.38        13
#         ACTIA       0.00      0.00      0.00        16
#       ADMINUI       0.00      0.00      0.00         2
#           ADS       0.78      0.50      0.61        28
#           ADV       0.00      0.00      0.00         5
#         AGILE       0.00      0.00      0.00         1
#           ALP       0.00      0.00      0.00        13
#      ALTTOSNX       0.00      0.00      0.00         1
#          AQUA       0.00      0.00      0.00         4
#            AR       1.00      0.18      0.30        17
#          ARAS       1.00      0.20      0.33        41
#           ASM       0.89      0.82      0.85        49
#           ASS       0.00      0.00      0.00         4
#          ASYS       1.00      0.45      0.62        20
#           BAH       0.00      0.00      0.00        13
#           BDT       0.00      0.00      0.00         8
#           BEC       0.00      0.00      0.00         5
#          BESI       0.00      0.00      0.00        11
#           BKH       0.00      0.00      0.00         2
#           BMN       1.00      0.57      0.72        23
#        BROOKS       0.00      0.00      0.00        10
#          BRUC       0.00      0.00      0.00         1
#            BU       0.92      0.64      0.75        36
#          BULT       0.00      0.00      0.00        10
#           CAR       0.97      0.81      0.88        47
#           CDS       1.00      0.15      0.27        26
#     CHDLTOSNX       0.00      0.00      0.00         3
#     CHDLTOZNX       0.00      0.00      0.00         1
#         CNTRO       0.00      0.00      0.00         5
#           COM       0.00      0.00      0.00         3
#       CONTACT       0.00      0.00      0.00        12
#           CRE       0.00      0.00      0.00         9
#          CSCH       0.00      0.00      0.00         2
#       CSTOSNX       0.00      0.00      0.00         1
#         CUBIC       0.00      0.00      0.00        16
#       DEMATIC       0.00      0.00      0.00         2
#        DEVOPS       0.00      0.00      0.00         2
#           DFF       1.00      0.64      0.78        28
#        DIONEX       1.00      0.44      0.62        27
#        DITTEL       0.00      0.00      0.00         4
#            DM       0.20      1.00      0.33       171
#           DMS       0.00      0.00      0.00         6
#           DOM       0.00      0.00      0.00         6
#           DRA       0.00      0.00      0.00         8
#        DRAPER       1.00      0.21      0.35        19
#            DS       1.00      0.90      0.95        29
#       DXTOSNX       1.00      0.18      0.31        11
#          ECTR       0.32      0.84      0.47       110
#           EGO       0.00      0.00      0.00         1
#           EIS       0.00      0.00      0.00         1
#           ELB       0.00      0.00      0.00         1
#           ELE       0.00      0.00      0.00         3
#           EMR       0.00      0.00      0.00         8
#          EPDM       0.90      0.97      0.93        80
#          ERBE       0.00      0.00      0.00         4
#          ERCO       1.00      0.10      0.18        10
#           EST       0.00      0.00      0.00         5
#           EWZ       0.75      0.30      0.43        10
#        FAMECC       0.00      0.00      0.00         6
#         FESTO       0.00      0.00      0.00         5
#          FILL       1.00      0.10      0.18        20
#        FINCAD       0.00      0.00      0.00         3
#           FRE       0.00      0.00      0.00         2
#         FRECH       0.00      0.00      0.00        10
#         GLUTH       0.00      0.00      0.00         6
#          GROB       0.00      0.00      0.00         1
#      GRUNDFOS       0.89      0.91      0.90        69
#          GRVE       0.00      0.00      0.00         1
#           HAR       0.00      0.00      0.00         5
#           HDH       0.86      0.68      0.76        44
#           HER       1.00      0.54      0.70        28
#           HOL       0.00      0.00      0.00         6
#        HOLCIM       0.00      0.00      0.00         4
#            HP       0.00      0.00      0.00         7
#           HUI       0.95      0.58      0.72        31
#        HWEBER       0.00      0.00      0.00        10
#          HYDR       0.00      0.00      0.00         4
#           IHC       0.00      0.00      0.00         7
#           IKA       0.00      0.00      0.00         9
#           IMA       0.82      0.82      0.82        38
#           INF       0.00      0.00      0.00         3
#          INSP       0.00      0.00      0.00         5
#           IPI       0.00      0.00      0.00         7
#           ISG       0.00      0.00      0.00        12
#           ISP       0.00      0.00      0.00         3
#          ITEL       0.00      0.00      0.00         3
#        JUNKER       1.00      0.35      0.51        26
#           KAL       0.00      0.00      0.00         4
#           KGS       0.00      0.00      0.00         8
#         KOIKE       0.00      0.00      0.00         4
#           KOL       0.00      0.00      0.00         5
#          KUKA       0.00      0.00      0.00        12
#           KVH       0.00      0.00      0.00         1
#           LAB       0.00      0.00      0.00         7
#        LAEMPE       0.00      0.00      0.00         8
#     LANDISGYR       0.00      0.00      0.00         4
#          LEAR       0.00      0.00      0.00         1
#          LEGO       0.00      0.00      0.00         3
#           LEO       0.00      0.00      0.00         5
#           LMD       1.00      0.13      0.24        15
#           LMO       0.00      0.00      0.00         2
#           MAG       0.00      0.00      0.00         3
#          MANZ       0.00      0.00      0.00        10
#         MAREL       1.00      0.14      0.25        14
#        MATRIX       0.00      0.00      0.00         5
#            MB       0.00      0.00      0.00         1
#           MED       0.00      0.00      0.00         1
#    MENTOREXTR       0.00      0.00      0.00         4
#         METRO       0.00      0.00      0.00         2
#         METSO       1.00      0.52      0.68        27
#            MG       0.00      0.00      0.00         5
#           MID       1.00      0.13      0.24        15
#         MITLL       1.00      0.06      0.11        18
#           MKB       0.00      0.00      0.00         9
#          MOOG       1.00      0.33      0.50        21
#           MWA       0.00      0.00      0.00         1
#           OER       1.00      0.62      0.77        29
#           OMM       0.00      0.00      0.00         4
#         ONTEC       0.00      0.00      0.00         7
#          OOTB       0.35      0.53      0.42        60
#       ORTOSNX       0.00      0.00      0.00         2
#      OTTOBOCK       0.00      0.00      0.00         3
#     PADSTOSNX       0.00      0.00      0.00         2
#           PDX       0.00      0.00      0.00         3
#           PGS       1.00      0.54      0.70        24
#           PHI       0.00      0.00      0.00         1
#            PI       0.94      0.65      0.77        46
#        PROCAD       0.00      0.00      0.00         9
#     PROMINENT       0.00      0.00      0.00         1
#          PROR       0.00      0.00      0.00         7
#   PROTELTOSNX       0.00      0.00      0.00         5
#           PRV       0.00      0.00      0.00         1
#           PSB       0.00      0.00      0.00         2
#           PTC       0.65      0.51      0.57        68
# PULSONIXTOSNX       0.00      0.00      0.00         3
#          REGA       0.00      0.00      0.00         3
#           REI       0.00      0.00      0.00         7
#           RHE       0.00      0.00      0.00         5
#           RUH       0.00      0.00      0.00         5
#           SAT       1.00      0.17      0.29        18
#           SAU       1.00      0.69      0.82        29
#           SDR       1.00      0.30      0.46        20
#       SDTOSNX       0.00      0.00      0.00         1
#           SEW       1.00      0.12      0.22        16
#           SIE       0.38      0.99      0.55       130
#           SIM       0.00      0.00      0.00         6
#         SLOAN       0.00      0.00      0.00         3
#          SMIT       0.89      0.89      0.89        56
#           SMP       0.00      0.00      0.00         8
#           SOR       1.00      0.07      0.12        15
#          SPAL       0.00      0.00      0.00         1
#          SPRP       1.00      0.33      0.50        15
#      STORENGY       0.00      0.00      0.00         3
#        STRAMA       1.00      0.40      0.57        20
#       STRATEC       0.00      0.00      0.00        15
#           SUP       0.00      0.00      0.00         2
#           SVC       0.37      0.66      0.47        93
#            SW       1.00      0.14      0.25        14
#           SWA       1.00      0.29      0.44        21
#           SWD       0.00      0.00      0.00         1
#           TBN       0.34      0.87      0.49        39
#          TEST       0.00      0.00      0.00         3
#        TESTIT       0.00      0.00      0.00        15
#           THO       0.00      0.00      0.00         1
#           THY       0.96      0.86      0.91        28
#           TKP       0.00      0.00      0.00         9
#         TURCK       0.59      0.87      0.70        60
#           UEC       0.00      0.00      0.00         8
#           VAT       0.00      0.00      0.00         6
#            VB       0.00      0.00      0.00         4
#           VIT       0.00      0.00      0.00         8
#           VMI       1.00      0.62      0.77        24
#           VOS       0.83      0.67      0.74        30
#         VRAIL       0.00      0.00      0.00         5
#          VSMN       0.00      0.00      0.00         9
#            VT       0.00      0.00      0.00         6
#          WALD       1.00      0.13      0.23        23
#       WASHTEC       1.00      0.40      0.57        10
#         WERMA       0.00      0.00      0.00         8
#          WILO       0.00      0.00      0.00        22
#           WTT       1.00      0.43      0.61        23
#         WWERK       0.00      0.00      0.00         2
#          XPLM       0.00      0.00      0.00         2
#         ZEISS       0.96      0.69      0.80        32
#           ZEP       0.00      0.00      0.00         8
#            ZF       0.00      0.00      0.00         1
#           ZSA       0.38      0.24      0.30        41
#          ZSYS       0.00      0.00      0.00         1
#          ZZZM       0.73      0.28      0.40        29
#
#      accuracy                           0.49      2835
#     macro avg       0.28      0.16      0.17      2835
#  weighted avg       0.57      0.49      0.44      2835

# %%
# SVM

# %%
classifier_svm = svm.SVC(kernel='linear',  probability=True)

# %%
## pipeline
model_svm = pipeline.Pipeline([("vectorizer", vectorizer),  
                           ("classifier", classifier_svm)])

# %%
# fit the training dataset on the classifier
model_svm["classifier"].fit(X_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=True, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %%
# predict the labels on validation dataset
predicted_svm = model_svm.predict(X_test)
print(predicted_svm)
# Out:
# ['ECTR' 'DM' 'BU' ... 'HOLCIM' 'ZSA' 'KOL']

# %%
print(metrics.classification_report(y_test, predicted_svm))
# Out:
# C:\Users\Elena\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   average_options = (None, 'micro', 'macro', 'weighted', 'samples')
#                precision    recall  f1-score   support
#
#           ACH       1.00      0.85      0.92        13
#         ACTIA       1.00      0.75      0.86        16
#       ADMINUI       0.00      0.00      0.00         2
#           ADS       1.00      0.79      0.88        28
#           ADV       0.80      0.80      0.80         5
#         AGILE       0.00      0.00      0.00         1
#           ALP       1.00      0.54      0.70        13
#      ALTTOSNX       0.00      0.00      0.00         1
#          AQUA       1.00      0.50      0.67         4
#            AR       0.85      0.65      0.73        17
#          ARAS       0.43      0.63      0.51        41
#           ASM       0.94      0.96      0.95        49
#           ASS       1.00      0.50      0.67         4
#          ASYS       1.00      0.95      0.97        20
#           BAH       1.00      0.69      0.82        13
#           BDT       1.00      0.75      0.86         8
#           BEC       1.00      1.00      1.00         5
#          BESI       0.90      0.82      0.86        11
#           BKH       0.00      0.00      0.00         2
#           BMN       0.95      0.87      0.91        23
#        BROOKS       1.00      0.80      0.89        10
#          BRUC       0.00      0.00      0.00         1
#            BU       0.70      0.86      0.78        36
#          BULT       1.00      0.70      0.82        10
#           CAR       0.98      0.89      0.93        47
#           CDS       0.86      0.73      0.79        26
#     CHDLTOSNX       1.00      0.67      0.80         3
#     CHDLTOZNX       0.00      0.00      0.00         1
#         CNTRO       1.00      0.80      0.89         5
#           COM       0.00      0.00      0.00         3
#       CONTACT       0.90      0.75      0.82        12
#           CRE       1.00      0.78      0.88         9
#          CSCH       1.00      0.50      0.67         2
#       CSTOSNX       0.00      0.00      0.00         1
#         CUBIC       1.00      0.75      0.86        16
#       DEMATIC       0.00      0.00      0.00         2
#        DEVOPS       0.00      0.00      0.00         2
#           DFF       1.00      0.93      0.96        28
#        DIONEX       0.85      0.85      0.85        27
#        DITTEL       1.00      0.25      0.40         4
#            DM       0.67      0.99      0.80       171
#           DMS       0.00      0.00      0.00         6
#           DOM       1.00      0.33      0.50         6
#           DRA       0.83      0.62      0.71         8
#        DRAPER       0.77      0.89      0.83        19
#            DS       1.00      1.00      1.00        29
#       DXTOSNX       0.77      0.91      0.83        11
#          ECTR       0.66      0.75      0.70       110
#           EGO       0.00      0.00      0.00         1
#           EIS       0.00      0.00      0.00         1
#           ELB       0.00      0.00      0.00         1
#           ELE       0.00      0.00      0.00         3
#           EMR       1.00      0.38      0.55         8
#          EPDM       0.97      0.97      0.97        80
#          ERBE       1.00      0.75      0.86         4
#          ERCO       0.86      0.60      0.71        10
#           EST       0.50      0.20      0.29         5
#           EWZ       0.75      0.90      0.82        10
#        FAMECC       0.75      0.50      0.60         6
#         FESTO       0.33      0.40      0.36         5
#          FILL       0.61      0.85      0.71        20
#        FINCAD       0.00      0.00      0.00         3
#           FRE       0.00      0.00      0.00         2
#         FRECH       1.00      0.90      0.95        10
#         GLUTH       1.00      1.00      1.00         6
#          GROB       0.00      0.00      0.00         1
#      GRUNDFOS       1.00      0.94      0.97        69
#          GRVE       0.00      0.00      0.00         1
#           HAR       0.75      0.60      0.67         5
#           HDH       0.67      0.89      0.76        44
#           HER       0.75      0.86      0.80        28
#           HOL       0.83      0.83      0.83         6
#        HOLCIM       1.00      0.75      0.86         4
#            HP       1.00      0.86      0.92         7
#           HUI       0.96      0.81      0.88        31
#        HWEBER       1.00      0.60      0.75        10
#          HYDR       0.00      0.00      0.00         4
#           IHC       1.00      0.71      0.83         7
#           IKA       1.00      0.78      0.88         9
#           IMA       0.97      0.92      0.95        38
#           INF       0.00      0.00      0.00         3
#          INSP       1.00      1.00      1.00         5
#           IPI       1.00      0.29      0.44         7
#           ISG       0.82      0.75      0.78        12
#           ISP       0.00      0.00      0.00         3
#          ITEL       1.00      0.33      0.50         3
#        JUNKER       0.96      0.85      0.90        26
#           KAL       1.00      0.75      0.86         4
#           KGS       1.00      0.88      0.93         8
#         KOIKE       0.00      0.00      0.00         4
#           KOL       1.00      0.60      0.75         5
#          KUKA       1.00      0.83      0.91        12
#           KVH       0.00      0.00      0.00         1
#           LAB       1.00      0.71      0.83         7
#        LAEMPE       1.00      0.62      0.77         8
#     LANDISGYR       0.00      0.00      0.00         4
#          LEAR       0.00      0.00      0.00         1
#          LEGO       0.00      0.00      0.00         3
#           LEO       1.00      0.40      0.57         5
#           LMD       0.75      0.80      0.77        15
#           LMO       0.00      0.00      0.00         2
#           MAG       0.00      0.00      0.00         3
#          MANZ       1.00      0.80      0.89        10
#         MAREL       1.00      0.93      0.96        14
#        MATRIX       0.00      0.00      0.00         5
#            MB       0.00      0.00      0.00         1
#           MED       0.00      0.00      0.00         1
#    MENTOREXTR       1.00      0.75      0.86         4
#         METRO       1.00      1.00      1.00         2
#         METSO       0.88      0.85      0.87        27
#            MG       1.00      1.00      1.00         5
#           MID       1.00      0.87      0.93        15
#         MITLL       1.00      0.78      0.88        18
#           MKB       1.00      0.78      0.88         9
#          MOOG       1.00      0.81      0.89        21
#           MWA       0.00      0.00      0.00         1
#           OER       0.74      0.90      0.81        29
#           OMM       1.00      0.50      0.67         4
#         ONTEC       1.00      0.86      0.92         7
#          OOTB       0.56      0.58      0.57        60
#       ORTOSNX       0.00      0.00      0.00         2
#      OTTOBOCK       0.50      0.33      0.40         3
#     PADSTOSNX       0.00      0.00      0.00         2
#           PDX       0.00      0.00      0.00         3
#           PGS       1.00      0.92      0.96        24
#           PHI       0.00      0.00      0.00         1
#            PI       1.00      0.89      0.94        46
#        PROCAD       0.62      0.56      0.59         9
#     PROMINENT       0.00      0.00      0.00         1
#          PROR       0.00      0.00      0.00         7
#   PROTELTOSNX       1.00      1.00      1.00         5
#           PRV       0.00      0.00      0.00         1
#           PSB       0.00      0.00      0.00         2
#           PTC       0.71      0.72      0.72        68
# PULSONIXTOSNX       1.00      0.33      0.50         3
#          REGA       1.00      0.67      0.80         3
#           REI       1.00      0.43      0.60         7
#           RHE       0.00      0.00      0.00         5
#           RUH       1.00      0.60      0.75         5
#           SAT       1.00      0.78      0.88        18
#           SAU       1.00      0.97      0.98        29
#           SDR       0.82      0.90      0.86        20
#       SDTOSNX       0.00      0.00      0.00         1
#           SEW       0.92      0.75      0.83        16
#           SIE       0.86      0.97      0.91       130
#           SIM       0.80      0.67      0.73         6
#         SLOAN       1.00      0.33      0.50         3
#          SMIT       0.95      0.93      0.94        56
#           SMP       1.00      0.75      0.86         8
#           SOR       0.92      0.80      0.86        15
#          SPAL       0.00      0.00      0.00         1
#          SPRP       0.82      0.93      0.87        15
#      STORENGY       1.00      0.67      0.80         3
#        STRAMA       1.00      0.85      0.92        20
#       STRATEC       1.00      0.73      0.85        15
#           SUP       0.00      0.00      0.00         2
#           SVC       0.38      0.77      0.51        93
#            SW       0.86      0.86      0.86        14
#           SWA       1.00      0.95      0.98        21
#           SWD       0.00      0.00      0.00         1
#           TBN       0.62      0.90      0.74        39
#          TEST       1.00      0.33      0.50         3
#        TESTIT       0.56      0.60      0.58        15
#           THO       0.00      0.00      0.00         1
#           THY       0.96      0.96      0.96        28
#           TKP       1.00      0.89      0.94         9
#         TURCK       0.77      0.82      0.79        60
#           UEC       1.00      0.50      0.67         8
#           VAT       1.00      1.00      1.00         6
#            VB       1.00      0.50      0.67         4
#           VIT       0.80      0.50      0.62         8
#           VMI       0.96      0.92      0.94        24
#           VOS       0.80      0.80      0.80        30
#         VRAIL       0.67      0.80      0.73         5
#          VSMN       1.00      0.67      0.80         9
#            VT       0.50      0.17      0.25         6
#          WALD       1.00      0.70      0.82        23
#       WASHTEC       1.00      0.80      0.89        10
#         WERMA       1.00      0.62      0.77         8
#          WILO       0.94      0.68      0.79        22
#           WTT       0.95      0.87      0.91        23
#         WWERK       0.00      0.00      0.00         2
#          XPLM       0.00      0.00      0.00         2
#         ZEISS       0.91      0.94      0.92        32
#           ZEP       1.00      0.75      0.86         8
#            ZF       0.00      0.00      0.00         1
#           ZSA       0.35      0.66      0.45        41
#          ZSYS       0.00      0.00      0.00         1
#          ZZZM       0.77      0.59      0.67        29
#
#      accuracy                           0.79      2835
#     macro avg       0.66      0.54      0.58      2835
#  weighted avg       0.80      0.79      0.78      2835

# %%
test_email = """
From: Walter, Martina
Sent: Friday, February 23, 2018 2:30 PM
To: support-ecad <support-ecad@xplm.com>
Cc: Simmat, Renato <renato.simmat@xplm.com>; Wilke, Beate <beate.wilke@xplm.com>
Subject: Urgent - Draeger Safety - Design Comparison
Importance: High

 

Hello,

 

Mr. Meves from Draeger Safety called and asked for urgent support re Design Comparison:

He has updated to Allegro 17.2 and Design Comparison does not work.

 

Other issue:

He need also a product package with release version which is installable.

Right now they need to pick up different installations.

 

I will also ask him to send log files or description if available.

 

BR Martina

 

Mit freundlichem Gruß / Best Regards

 

Martina Walter

Senior Business Administrator

 

XPLM Solution GmbH

Heinrich-Hertz-Str. 4

79211 Denzlingen, Germany

www.xplm.com

martina.walter@xplm.com

 

Office: +49 7666 90398-511 (neue Nummer) / Fax: +49 7666 90398-520

 

Registergericht / Commercial Register Dresden: HRB 24804

Geschäftsführer / Managing Directors: Rolf Pfenning, Karl Wachtel

 

Der Inhalt dieser E-Mail ist vertraulich und ausschließlich für den bezeichneten Adressaten bestimmt. Wenn Sie nicht der vorgesehene Adressat dieser E-Mail oder dessen Vertreter sein sollten, so beachten Sie bitte, dass jede Form der Kenntnisnahme, Veröffentlichung, Vervielfältigung oder Weitergabe des Inhalts dieser Mail unzulässig ist. Wir bitten Sie, sich in diesem Fall mit dem Absender der E-Mail in Verbindung zu setzen.

 

This e-mail message including any attachments is for the sole use of the intended recipient(s) and may contain privileged or confidential information. Any unauthorized review, use, disclosure or distribution is prohibited. If you are not the intended recipient, please immediately contact the sender by reply e-mail and delete the original message and destroy all copies thereof.
"""

# %%
test_email_pr = utils_preprocess_text(test_email, flg_stemm=True, flg_lemm=False, 
          lst_stopwords=lst_stopwords)

# %%
model_svm.predict([test_email_pr])
# Out:
# array(['DM'], dtype=object)

# %%
prob = model_svm.predict_proba([test_email_pr])

# %%
for i in range(len(prob[0])):
    print(prob[0][i],classes[i])
# Out:
# 0.003996905354254787 ACH
# 0.0034672897290130805 ACTIA
# 0.001911553775351473 ADMINUI
# 0.006822001691244931 ADS
# 0.0027243974532785804 ADV
# 0.0010813522514441423 AGILE
# 0.003057473272169369 ALP
# 0.0004411693383703346 ALTTOSNX
# 0.003147224171368263 AQUA
# 0.002309956650885201 AR
# 0.013735763854535718 ARAS
# 0.006780152398915884 ASM
# 0.0007474882947346228 ASS
# 0.009356511208944143 ASYS
# 0.005756184476807511 BAH
# 0.0022346290298092273 BDT
# 0.000676310439833337 BEC
# 0.0018071577384684025 BESI
# 0.003199505114493518 BKH
# 0.00331689252773582 BMN
# 0.002610056903332479 BROOKS
# 0.0011542835067808585 BRUC
# 0.011267849479074055 BU
# 0.006816729834734308 BULT
# 0.008883850263055432 CAR
# 0.0041412845841350574 CDS
# 0.0009542469604379312 CHDLTOSNX
# 0.0003588051893523525 CHDLTOZNX
# 0.0022174437776888833 CNTRO
# 0.001734621768213786 COM
# 0.0036546005357495285 CONTACT
# 0.002537233201748176 CRE
# 0.0009568025980063251 CSCH
# 0.003303861040024308 CSTOSNX
# 0.0020871504988280915 CUBIC
# 0.0017826129688131068 DEMATIC
# 0.0013120519348186204 DEVOPS
# 0.0076523796178462646 DFF
# 0.008861385417208763 DIONEX
# 0.006706925098229754 DITTEL
# 0.07113176603709079 DM
# 0.0031932783633423284 DMS
# 0.002525459852183672 DOM
# 0.06101327729218387 DRA
# 0.005199876517840866 DRAPER
# 0.009265167684129761 DS
# 0.0014093368606503582 DXTOSNX
# 0.014698843345861565 ECTR
# 0.0008988434966837416 EGO
# 0.00048005494101556137 EIS
# 0.0010309229697478984 ELB
# 0.0046344726581541 ELE
# 0.0018532323489441262 EMR
# 0.017455157126455137 EPDM
# 0.0015013839844222965 ERBE
# 0.0023863807113291683 ERCO
# 0.0036866840890942836 EST
# 0.002773586338156322 EWZ
# 0.003231734001376413 FAMECC
# 0.0008227403226318341 FESTO
# 0.009285916822719568 FILL
# 0.002332502873629333 FINCAD
# 0.0014054180836285245 FRE
# 0.0017463023447000436 FRECH
# 0.003162392606343548 GLUTH
# 0.0004728896634305961 GROB
# 0.004038595195302654 GRUNDFOS
# 0.0013542244070556943 GRVE
# 0.0012776412059216605 HAR
# 0.012556989271371251 HDH
# 0.006978640084474928 HER
# 0.002702603303326041 HOL
# 0.0014650263960367218 HOLCIM
# 0.003783526561171716 HP
# 0.008557122081779943 HUI
# 0.002016357489597522 HWEBER
# 0.009122260710359553 HYDR
# 0.006637381421511305 IHC
# 0.0013956750547716751 IKA
# 0.0065964315672300865 IMA
# 0.0022746410382106096 INF
# 0.0008526910918072387 INSP
# 0.009542620886791546 IPI
# 0.00424722091393497 ISG
# 0.0030156280960345564 ISP
# 0.0025877973754841015 ITEL
# 0.009495478373231574 JUNKER
# 0.001360509958679407 KAL
# 0.0016125660285502897 KGS
# 0.008054413973528048 KOIKE
# 0.0012010885295227927 KOL
# 0.005979895276984867 KUKA
# 0.0004803391875640995 KVH
# 0.008160370747386389 LAB
# 0.0017418646754545609 LAEMPE
# 0.010565136280673642 LANDISGYR
# 0.0020437762841548483 LEAR
# 0.00281862883776362 LEGO
# 0.0010751624470220777 LEO
# 0.00673791901605909 LMD
# 0.002418245113388908 LMO
# 0.003679416388375429 MAG
# 0.0015482044026720776 MANZ
# 0.0024770452157500565 MAREL
# 0.005372802655598474 MATRIX
# 0.000863370003582282 MB
# 0.0005136919899838951 MED
# 0.0012198272357733652 MENTOREXTR
# 0.0006429749810929962 METRO
# 0.009738713446586195 METSO
# 0.001126546083210587 MG
# 0.0065452096632068356 MID
# 0.004987787690905513 MITLL
# 0.002076157062502318 MKB
# 0.004520348988400069 MOOG
# 0.0004505468409456218 MWA
# 0.008876320877340294 OER
# 0.0024354804254960016 OMM
# 0.0014280643729242082 ONTEC
# 0.0142730376469559 OOTB
# 0.002151391764416778 ORTOSNX
# 0.0010056527841644642 OTTOBOCK
# 0.0019209067771215243 PADSTOSNX
# 0.0047743100157873995 PDX
# 0.003028303265819403 PGS
# 0.002650941661937956 PHI
# 0.01209422356390817 PI
# 0.004497733127933197 PROCAD
# 0.00046162800772322934 PROMINENT
# 0.007682177942272401 PROR
# 0.0022907780812191766 PROTELTOSNX
# 0.00041238730251109994 PRV
# 0.0019497596172829922 PSB
# 0.017314761976960198 PTC
# 0.0009917410192822422 PULSONIXTOSNX
# 0.0013847988563252351 REGA
# 0.003008017306107993 REI
# 0.0031640061368546596 RHE
# 0.003131601744792896 RUH
# 0.006371986577615126 SAT
# 0.008189576141682198 SAU
# 0.004058297473415763 SDR
# 0.0019046970594528956 SDTOSNX
# 0.007313642344812002 SEW
# 0.0293912391116069 SIE
# 0.0013566932780759782 SIM
# 0.004373327454730696 SLOAN
# 0.006128651783942787 SMIT
# 0.0013367144800527004 SMP
# 0.025552934852133197 SOR
# 0.0004283130865431095 SPAL
# 0.0048308313917784975 SPRP
# 0.0014023888425164946 STORENGY
# 0.003954863560568961 STRAMA
# 0.005069272294618952 STRATEC
# 0.0020828693012892355 SUP
# 0.03223674459953989 SVC
# 0.004583977757077837 SW
# 0.004162882624887508 SWA
# 0.0004685585248908581 SWD
# 0.014634431002197065 TBN
# 0.0013079195455289688 TEST
# 0.0025778156753012028 TESTIT
# 0.0017320612892562268 THO
# 0.003460354261666005 THY
# 0.004628015578180715 TKP
# 0.011151071018827011 TURCK
# 0.0020011337959595413 UEC
# 0.0019360725486236357 VAT
# 0.0008776501334485242 VB
# 0.001790843216426761 VIT
# 0.0022154673794508375 VMI
# 0.00807666505625618 VOS
# 0.0019115811944688623 VRAIL
# 0.0025058951426310495 VSMN
# 0.0033942825867769874 VT
# 0.006772502640519316 WALD
# 0.0009867654212913578 WASHTEC
# 0.002208660854850475 WERMA
# 0.011642626908403068 WILO
# 0.009351529431522272 WTT
# 0.0013168338388007239 WWERK
# 0.0029599624740318086 XPLM
# 0.004054810241741453 ZEISS
# 0.0014002870979069315 ZEP
# 0.0018475127063819067 ZF
# 0.04037469942864589 ZSA
# 0.00045970231107012537 ZSYS
# 0.01262353358726082 ZZZM

# %%
test_email1 = """
From: Voillat, Lionel [mailto:lionel.voillat@siemens.com] 
Sent: Monday, November 20, 2017 7:54 PM
To: support-ecad <support-ecad@xplm.com>
Cc: Hutsch, Marc <Marc.Hutsch@xplm.com>
Subject: TC_1.0_Altium - error on start

Hello,

I work at Siemens Industry Software as Presales (Mechatronics) for Switzerland / Austria and have a problem with your TC_1.0_Altium interface (see attachment). I installed and configured the interface (according to readme.txt) but it doesn't work. I see the "Integrate" window, then nothing more happens.

Seems to be the following problems:
*********
2017-11-20 14:27:10 DEBUG Caught StandardError: IVS is not available or incompatible:
Error: OpenTimeout
Message: "execution expired"
*********

I would be happy if you could call me back to solve my problem or email me a possible solution.

Yours sincerely.

Lionel Voillat
Presales PLM / CAD-Central / Eastern Europe
Global Sales & Services

Siemens Industry Software AG
Digital Factory Division
Product lifecycle management
Central & Eastern Europe
DF PL S&SE EU COE BD PSA
Freilagerstrasse 40
8047 Zurich, Switzerland
Tel.: +41 (0) 44 755 72 93
Fax: +41 (0) 44 755 72 70
Mobile: +41 (0) 79 346 68 28
lionel.voillat@siemens.com
www.siemens.com/plm 
More about this source textSource text required for additional translation information
Send feedback
Side panels
"""

# %%
test_email1_pr = preprocess_text(test_email1, flg_stemm=True, flg_lemm=False, 
          lst_stopwords=lst_stopwords)

# %%
model_svm.predict([test_email1_pr])
# Out:
# array(['SIE'], dtype=object)

# %%
prob1 = model_svm.predict_proba([test_email1_pr])

# %%
classes = np.unique(y_test)

# %%
for i in range(len(prob1[0])):
    print(prob1[0][i],classes[i])
# Out:
# 0.0019692925729733785 ACH
# 0.003848901238983346 ACTIA
# 0.001571985257829976 ADMINUI
# 0.0049816111076507125 ADS
# 0.0014128355837232528 ADV
# 0.0008297759418025174 AGILE
# 0.002789299162343698 ALP
# 0.0003410210570338041 ALTTOSNX
# 0.0018662303118673503 AQUA
# 0.003891016017322934 AR
# 0.011262602936464127 ARAS
# 0.05409434294475272 ASM
# 0.0005869195081306493 ASS
# 0.004709754737372666 ASYS
# 0.003782911800345254 BAH
# 0.0017221462744394559 BDT
# 0.0005660697937911033 BEC
# 0.0019062965112020365 BESI
# 0.0032304399181135855 BKH
# 0.0022777005233462645 BMN
# 0.0031422759955554757 BROOKS
# 0.0009103412027239866 BRUC
# 0.007596056399967188 BU
# 0.0038522882482610794 BULT
# 0.007145691372177933 CAR
# 0.005499886291442115 CDS
# 0.0006902947594497416 CHDLTOSNX
# 0.0003162724923852529 CHDLTOZNX
# 0.0010746493033414828 CNTRO
# 0.0013773986725137276 COM
# 0.0021438328045232653 CONTACT
# 0.003295671093784862 CRE
# 0.0006513039753075182 CSCH
# 0.00102483060577782 CSTOSNX
# 0.0021205696896259884 CUBIC
# 0.0021029581195699163 DEMATIC
# 0.0012232227980360172 DEVOPS
# 0.0058126858340179 DFF
# 0.007693208436662435 DIONEX
# 0.0055960383703919205 DITTEL
# 0.046791666797906396 DM
# 0.002562216886310923 DMS
# 0.0023480332807550557 DOM
# 0.0017618325587847505 DRA
# 0.002585090909654855 DRAPER
# 0.005472395279085026 DS
# 0.0012355907475284683 DXTOSNX
# 0.016563708978313583 ECTR
# 0.0009368644377883211 EGO
# 0.0003365579519025654 EIS
# 0.0008154329300517685 ELB
# 0.004433810981363948 ELE
# 0.0015417146651827325 EMR
# 0.0083502648948865 EPDM
# 0.0010038909822007544 ERBE
# 0.0013478909920299287 ERCO
# 0.003867024798862139 EST
# 0.002694424932114806 EWZ
# 0.006757769657192569 FAMECC
# 0.000581207185563151 FESTO
# 0.00540221673229698 FILL
# 0.0013040178141165127 FINCAD
# 0.0012265599289619572 FRE
# 0.001852686111590529 FRECH
# 0.0019412982881350912 GLUTH
# 0.000329347711340109 GROB
# 0.0037107878653430586 GRUNDFOS
# 0.0009540885492698175 GRVE
# 0.001173950800382075 HAR
# 0.011835599245529052 HDH
# 0.004351615167613888 HER
# 0.0037873499148598647 HOL
# 0.0010618015564656173 HOLCIM
# 0.003588520926442555 HP
# 0.005248909604169346 HUI
# 0.0028337378288623843 HWEBER
# 0.0030224671200402694 HYDR
# 0.0037476683180718484 IHC
# 0.00096249571411073 IKA
# 0.003752009794374045 IMA
# 0.003835547939998474 INF
# 0.0007899564205404926 INSP
# 0.007495331190338105 IPI
# 0.0022640056332459 ISG
# 0.0028651554984541173 ISP
# 0.002192955574099254 ITEL
# 0.004390567857433224 JUNKER
# 0.0006771246657497719 KAL
# 0.0009272928283023331 KGS
# 0.00577212693652095 KOIKE
# 0.0010926399119921858 KOL
# 0.0023281055272928322 KUKA
# 0.0003301578913187432 KVH
# 0.004099005894837586 LAB
# 0.0015985691329757359 LAEMPE
# 0.003175934507236911 LANDISGYR
# 0.0014426618576258278 LEAR
# 0.009070694067433724 LEGO
# 0.0009479227359881929 LEO
# 0.0032037040719758124 LMD
# 0.003835461934160953 LMO
# 0.008627467994179865 MAG
# 0.0011116268968001334 MANZ
# 0.00196059189487187 MAREL
# 0.006200340714776984 MATRIX
# 0.0007087609366395069 MB
# 0.000357361788314764 MED
# 0.0010170178939357935 MENTOREXTR
# 0.0005901077347049034 METRO
# 0.015502100584252004 METSO
# 0.001225011741796618 MG
# 0.004549156814453135 MID
# 0.002495493208442791 MITLL
# 0.0016049417878992165 MKB
# 0.0018524700324402596 MOOG
# 0.00032820097880650016 MWA
# 0.00809450870574353 OER
# 0.0013852773202900673 OMM
# 0.0007333250484274918 ONTEC
# 0.011307371588524653 OOTB
# 0.0013434983100309246 ORTOSNX
# 0.0008342553040636411 OTTOBOCK
# 0.0015284035736054385 PADSTOSNX
# 0.006967168444096612 PDX
# 0.003185329794707771 PGS
# 0.0019318338296082616 PHI
# 0.017583951956638692 PI
# 0.0041361337177618935 PROCAD
# 0.00030416995240914674 PROMINENT
# 0.00547589758533416 PROR
# 0.002158497223760081 PROTELTOSNX
# 0.0003143309879931013 PRV
# 0.0021107718017703662 PSB
# 0.0315937373221201 PTC
# 0.0007298883417923426 PULSONIXTOSNX
# 0.0012100810653295996 REGA
# 0.0031064851974652212 REI
# 0.0036952971870952986 RHE
# 0.0022238160159134116 RUH
# 0.005046815676535313 SAT
# 0.0037122326603605442 SAU
# 0.0034110916574481686 SDR
# 0.0014063496312412029 SDTOSNX
# 0.007301136556106359 SEW
# 0.20057729438389404 SIE
# 0.0011896678900181763 SIM
# 0.0024786957166481284 SLOAN
# 0.014204452417255787 SMIT
# 0.0010283185843395425 SMP
# 0.0077684080300888395 SOR
# 0.0003288550907652293 SPAL
# 0.0016405031450339278 SPRP
# 0.0011311828584520814 STORENGY
# 0.0036975756723450002 STRAMA
# 0.0034683481238251108 STRATEC
# 0.0019163245593076831 SUP
# 0.0402943353295246 SVC
# 0.004581242978450191 SW
# 0.009785477590450061 SWA
# 0.0003264848502858327 SWD
# 0.012217637463526049 TBN
# 0.0011069500410437483 TEST
# 0.003580712811938345 TESTIT
# 0.0014489443885629164 THO
# 0.003642694775475173 THY
# 0.001246095071680668 TKP
# 0.010773904433171519 TURCK
# 0.0015766367029151328 UEC
# 0.0016448431229631342 VAT
# 0.0007196510658635626 VB
# 0.0018215674616748306 VIT
# 0.003908422987191307 VMI
# 0.00521042079138916 VOS
# 0.001720537146935832 VRAIL
# 0.0022218063669590575 VSMN
# 0.0011343199016569298 VT
# 0.002652773994095228 WALD
# 0.0011782311514896098 WASHTEC
# 0.0013266592100742065 WERMA
# 0.003626952588314227 WILO
# 0.005512764890495708 WTT
# 0.001168500105486883 WWERK
# 0.002940128358421447 XPLM
# 0.002861171812695215 ZEISS
# 0.0011124076953450046 ZEP
# 0.0016115000962581756 ZF
# 0.02302142045766495 ZSA
# 0.00032230816729008255 ZSYS
# 0.015990491678270328 ZZZM

# %%
# сохранение обученной модели

# %%
import pickle

# %%
Pkl_Filename = "company_name_model_svm.pkl"

# %%
with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(model_svm, file)

# %%
# загрузка обученной модели
with open(Pkl_Filename, 'rb') as file:  
    Pickled_LR_Model = pickle.load(file)

prob2 = Pickled_LR_Model.predict_proba([test_email_pr])

# %%
for i in range(len(prob2[0])):
    print(prob2[0][i],classes[i])
# Out:
# 0.003996905354254787 ACH
# 0.0034672897290130805 ACTIA
# 0.001911553775351473 ADMINUI
# 0.006822001691244931 ADS
# 0.0027243974532785804 ADV
# 0.0010813522514441423 AGILE
# 0.003057473272169369 ALP
# 0.0004411693383703346 ALTTOSNX
# 0.003147224171368263 AQUA
# 0.002309956650885201 AR
# 0.013735763854535718 ARAS
# 0.006780152398915884 ASM
# 0.0007474882947346228 ASS
# 0.009356511208944143 ASYS
# 0.005756184476807511 BAH
# 0.0022346290298092273 BDT
# 0.000676310439833337 BEC
# 0.0018071577384684025 BESI
# 0.003199505114493518 BKH
# 0.00331689252773582 BMN
# 0.002610056903332479 BROOKS
# 0.0011542835067808585 BRUC
# 0.011267849479074055 BU
# 0.006816729834734308 BULT
# 0.008883850263055432 CAR
# 0.0041412845841350574 CDS
# 0.0009542469604379312 CHDLTOSNX
# 0.0003588051893523525 CHDLTOZNX
# 0.0022174437776888833 CNTRO
# 0.001734621768213786 COM
# 0.0036546005357495285 CONTACT
# 0.002537233201748176 CRE
# 0.0009568025980063251 CSCH
# 0.003303861040024308 CSTOSNX
# 0.0020871504988280915 CUBIC
# 0.0017826129688131068 DEMATIC
# 0.0013120519348186204 DEVOPS
# 0.0076523796178462646 DFF
# 0.008861385417208763 DIONEX
# 0.006706925098229754 DITTEL
# 0.07113176603709079 DM
# 0.0031932783633423284 DMS
# 0.002525459852183672 DOM
# 0.06101327729218387 DRA
# 0.005199876517840866 DRAPER
# 0.009265167684129761 DS
# 0.0014093368606503582 DXTOSNX
# 0.014698843345861565 ECTR
# 0.0008988434966837416 EGO
# 0.00048005494101556137 EIS
# 0.0010309229697478984 ELB
# 0.0046344726581541 ELE
# 0.0018532323489441262 EMR
# 0.017455157126455137 EPDM
# 0.0015013839844222965 ERBE
# 0.0023863807113291683 ERCO
# 0.0036866840890942836 EST
# 0.002773586338156322 EWZ
# 0.003231734001376413 FAMECC
# 0.0008227403226318341 FESTO
# 0.009285916822719568 FILL
# 0.002332502873629333 FINCAD
# 0.0014054180836285245 FRE
# 0.0017463023447000436 FRECH
# 0.003162392606343548 GLUTH
# 0.0004728896634305961 GROB
# 0.004038595195302654 GRUNDFOS
# 0.0013542244070556943 GRVE
# 0.0012776412059216605 HAR
# 0.012556989271371251 HDH
# 0.006978640084474928 HER
# 0.002702603303326041 HOL
# 0.0014650263960367218 HOLCIM
# 0.003783526561171716 HP
# 0.008557122081779943 HUI
# 0.002016357489597522 HWEBER
# 0.009122260710359553 HYDR
# 0.006637381421511305 IHC
# 0.0013956750547716751 IKA
# 0.0065964315672300865 IMA
# 0.0022746410382106096 INF
# 0.0008526910918072387 INSP
# 0.009542620886791546 IPI
# 0.00424722091393497 ISG
# 0.0030156280960345564 ISP
# 0.0025877973754841015 ITEL
# 0.009495478373231574 JUNKER
# 0.001360509958679407 KAL
# 0.0016125660285502897 KGS
# 0.008054413973528048 KOIKE
# 0.0012010885295227927 KOL
# 0.005979895276984867 KUKA
# 0.0004803391875640995 KVH
# 0.008160370747386389 LAB
# 0.0017418646754545609 LAEMPE
# 0.010565136280673642 LANDISGYR
# 0.0020437762841548483 LEAR
# 0.00281862883776362 LEGO
# 0.0010751624470220777 LEO
# 0.00673791901605909 LMD
# 0.002418245113388908 LMO
# 0.003679416388375429 MAG
# 0.0015482044026720776 MANZ
# 0.0024770452157500565 MAREL
# 0.005372802655598474 MATRIX
# 0.000863370003582282 MB
# 0.0005136919899838951 MED
# 0.0012198272357733652 MENTOREXTR
# 0.0006429749810929962 METRO
# 0.009738713446586195 METSO
# 0.001126546083210587 MG
# 0.0065452096632068356 MID
# 0.004987787690905513 MITLL
# 0.002076157062502318 MKB
# 0.004520348988400069 MOOG
# 0.0004505468409456218 MWA
# 0.008876320877340294 OER
# 0.0024354804254960016 OMM
# 0.0014280643729242082 ONTEC
# 0.0142730376469559 OOTB
# 0.002151391764416778 ORTOSNX
# 0.0010056527841644642 OTTOBOCK
# 0.0019209067771215243 PADSTOSNX
# 0.0047743100157873995 PDX
# 0.003028303265819403 PGS
# 0.002650941661937956 PHI
# 0.01209422356390817 PI
# 0.004497733127933197 PROCAD
# 0.00046162800772322934 PROMINENT
# 0.007682177942272401 PROR
# 0.0022907780812191766 PROTELTOSNX
# 0.00041238730251109994 PRV
# 0.0019497596172829922 PSB
# 0.017314761976960198 PTC
# 0.0009917410192822422 PULSONIXTOSNX
# 0.0013847988563252351 REGA
# 0.003008017306107993 REI
# 0.0031640061368546596 RHE
# 0.003131601744792896 RUH
# 0.006371986577615126 SAT
# 0.008189576141682198 SAU
# 0.004058297473415763 SDR
# 0.0019046970594528956 SDTOSNX
# 0.007313642344812002 SEW
# 0.0293912391116069 SIE
# 0.0013566932780759782 SIM
# 0.004373327454730696 SLOAN
# 0.006128651783942787 SMIT
# 0.0013367144800527004 SMP
# 0.025552934852133197 SOR
# 0.0004283130865431095 SPAL
# 0.0048308313917784975 SPRP
# 0.0014023888425164946 STORENGY
# 0.003954863560568961 STRAMA
# 0.005069272294618952 STRATEC
# 0.0020828693012892355 SUP
# 0.03223674459953989 SVC
# 0.004583977757077837 SW
# 0.004162882624887508 SWA
# 0.0004685585248908581 SWD
# 0.014634431002197065 TBN
# 0.0013079195455289688 TEST
# 0.0025778156753012028 TESTIT
# 0.0017320612892562268 THO
# 0.003460354261666005 THY
# 0.004628015578180715 TKP
# 0.011151071018827011 TURCK
# 0.0020011337959595413 UEC
# 0.0019360725486236357 VAT
# 0.0008776501334485242 VB
# 0.001790843216426761 VIT
# 0.0022154673794508375 VMI
# 0.00807666505625618 VOS
# 0.0019115811944688623 VRAIL
# 0.0025058951426310495 VSMN
# 0.0033942825867769874 VT
# 0.006772502640519316 WALD
# 0.0009867654212913578 WASHTEC
# 0.002208660854850475 WERMA
# 0.011642626908403068 WILO
# 0.009351529431522272 WTT
# 0.0013168338388007239 WWERK
# 0.0029599624740318086 XPLM
# 0.004054810241741453 ZEISS
# 0.0014002870979069315 ZEP
# 0.0018475127063819067 ZF
# 0.04037469942864589 ZSA
# 0.00045970231107012537 ZSYS
# 0.01262353358726082 ZZZM

# %%
X_train
# Out:
# <6596x6135 sparse matrix of type '<class 'numpy.float64'>'
# 	with 139444 stored elements in Compressed Sparse Row format>

# %%
y_train.shape
# Out:
# (6596,)

# %%
nltk.__version__
# Out:
# '3.4.5'

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '0.22.1'

# %%
from sklearn.model_selection import StratifiedKFold,cross_val_score

# %%
# stratified k fold
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)
# enumerate the splits and summarize the distributions
for train_ix, test_ix in kfold.split(X, Y):
    # select rows
    X_train, X_test = X[train_ix], X[test_ix]
    Y_train, Y_test = Y[train_ix], Y[test_ix]
    # summarize train and test composition
    model_svm.fit(X_train,Y_train)
    predictions = model_svm.predict(X_test)
    print('Accuracy:',accuracy_score(Y_test,predictions))
# Out:
# C:\Users\Elena\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# Accuracy: 0.8178114086146682
# Accuracy: 0.8084982537834692
# Accuracy: 0.810826542491269
# Accuracy: 0.8020954598370198
# Accuracy: 0.7968568102444703

# %%
X = data_jira_en["text_clean"].values

# %%
Y = data_jira_en["company"].values

# %%
# cosine simularity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
X_train
# Out:
# <5755x5164 sparse matrix of type '<class 'numpy.float64'>'
# 	with 77405 stored elements in Compressed Sparse Row format>

# %%
test_email2 = data_jira_en["text"].values[3]

# %%
test_email2_pr = preprocess_text(test_email2, flg_stemm=True, flg_lemm=False, 
          lst_stopwords=lst_stopwords)

# %%
email_vector2 = vectorizer.fit_transform([test_email2_pr])

# %%
cosine_sim = cosine_similarity(email_vector2,X_train).flatten()

# %%
cosine_sim
# Out:
# array([0.        , 0.        , 0.02679404, ..., 0.        , 0.01795977,
#        0.        ])

# %%
# 5 наиболее похожих текстов
docs_indexes = cosine_sim.argsort()[:-5:-1]
docs_indexes
# Out:
# array([3723, 1688,  987, 5045], dtype=int64)

# %%
cosine_sim[docs_indexes]
# Out:
# array([0.96702668, 0.74645723, 0.74645723, 0.74645723])

# %%
best_mail = dtf_train["text"].values[docs_indexes[0]]

# %%
best_mail
# Out:
# '{html} **From:** E.Amez@achenbach.de  \r\n **Sent:** 29-May-17 12:20:07 PM  \r\n **To:** support-ecad  \r\n **Subject:** [ACH] EPLAN: problem report  \r\n  \r\n\r\nPlease find problem related files in zip archive attached.\r\n\r\n{html}\r\n\r\n'

# %%
test_email2
# Out:
# '{html} **From:** E.Amez@achenbach.de  \r\n **Sent:** 29-May-17 11:38:42 AM  \r\n **To:** support-ecad  \r\n **Subject:** [ACH] EPLAN: problem report  \r\n  \r\n\r\nPlease find problem related files in zip archive attached.\r\n\r\n{html}\r\n\r\n'

# %%
cross_val_score(model,X,Y,cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=1))
# Out:
# C:\Users\Elena\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# array([0.49476257, 0.50611247, 0.49842822])

# %%
cross_val_score(model_svm,X,Y,cv=StratifiedKFold(n_splits=3, shuffle=True, random_state=1))
# Out:
# C:\Users\Elena\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# array([0.80027933, 0.79811387, 0.78833392])
